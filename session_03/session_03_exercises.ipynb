# %% [markdown]
# # 📓 Session 3 · Exercises
# ### NumPy, pandas, and matplotlib
#
# Last session you wrote the loops yourself. These exercises are about handing that work to three packages, so you can ask bigger questions of a much bigger table.
#
# Most tasks ask you to write or complete a short piece of code. They start easy and build up, and they all use the same real price data as the lecture.

# %% [markdown]
# ## How to use this notebook
#
# - Run the **setup cell** below first. It imports the three packages and loads the price data, and every exercise uses what it creates.
# - Each exercise has a **task**, then a **code cell** for your work. Cells with `...` are blanks to fill in. Replace them with real code.
# - Stuck? Open the **💡 Hint**, but only after a genuine attempt. Open the **✅ Solution** to *check* yourself, not to skip the thinking.
# - Every cell runs cleanly even with the blanks still in place, so pressing **Run all** never floods you with errors.
# - Exercises do not depend on each other. If one defeats you, move on.
#
# **You are not expected to finish all of these.** Do what you can, and come back to the rest when you revise. Short on time? Read the hint, then the solution. A worked solution you genuinely understand is real learning too.

# %% [markdown]
# ### Difficulty
#
# | badge | what to expect |
# |:--|:--|
# | ★☆☆☆☆ | One step, straight from the lecture. You are checking that you can type it. |
# | ★★☆☆☆ | The same idea on new data, or two steps in a row. Nothing to decide. |
# | ★★★☆☆ | Combine two ideas, or adapt a pattern rather than copy it. |
# | ★★★★☆ | You choose the approach. Several steps, and something has to be worked out before you type. |
# | ★★★★★ | A genuine puzzle: an insight, or a constraint that rules out the obvious route. Always solvable with what you have. |
#
# The stars rate the work against **this** session. A three-star task in a later notebook assumes everything before it, so it is a bigger piece of work than a three-star task here, even though both sit in the middle of their own scale.
#
# Some exercises also carry a **revisits** tag. Those need something from an earlier session as well as today's material, and they are there on purpose: the skills are meant to accumulate, not to be handed in at the end of each week.

# %% [markdown]
# ## 🧰 Your toolkit for today
#
# Everything you need is on this card, plus everything from Sessions 1 and 2. Only section **K** goes past it, deliberately: that section is about looking things up, which is the skill that matters most once a package has hundreds of functions.
#
# > Names in brackets (`values`, `frame`, `column`, ...) are **placeholders**: put your own variable there. **Hover any tool** to see what it does.
#
# <p style="line-height:2.1"><strong>NumPy arrays</strong><br>
# <code style="cursor:help" title="Turn a list of numbers into an array, which does arithmetic on every element at once.">np.array(list)</code> &nbsp;&nbsp; <code style="cursor:help" title="How many rows and columns. For a 1-D array it prints as (n,).">values.shape</code> &nbsp;&nbsp; <code style="cursor:help" title="Everything from position 1 onwards. Same slicing as a list.">values[1:]</code> &nbsp;&nbsp; <code style="cursor:help" title="Everything except the last element.">values[:-1]</code> &nbsp;&nbsp; <code style="cursor:help" title="The square root, element by element.">np.sqrt(x)</code></p>
#
# <p style="line-height:2.1"><strong>Summarising an array</strong><br>
# <code style="cursor:help" title="The average of the values.">values.mean()</code> &nbsp;&nbsp; <code style="cursor:help" title="The standard deviation, which is what volatility is.">values.std()</code> &nbsp;&nbsp; <code style="cursor:help" title="The smallest value.">values.min()</code> &nbsp;&nbsp; <code style="cursor:help" title="The largest value.">values.max()</code> &nbsp;&nbsp; <code style="cursor:help" title="Add every value up.">values.sum()</code></p>
#
# <p style="line-height:2.1"><strong>Asking a question of every element</strong><br>
# <code style="cursor:help" title="An array of True and False, one per element.">values &gt; 0</code> &nbsp;&nbsp; <code style="cursor:help" title="Keep only the elements where the condition is True.">values[values &gt; 0]</code> &nbsp;&nbsp; <code style="cursor:help" title="Count the Trues, because True counts as 1.">(values &gt; 0).sum()</code></p>
#
# <p style="line-height:2.1"><strong>Matrices</strong><br>
# <code style="cursor:help" title="A 2-D array: a list of rows, each row a list of numbers.">np.array([[1, 2], [3, 4]])</code> &nbsp;&nbsp; <code style="cursor:help" title="One element: row 0, column 1. Rows first, then columns.">X[0, 1]</code> &nbsp;&nbsp; <code style="cursor:help" title="A whole row, or a whole column. The colon means all of them.">X[0, :]</code> &nbsp;&nbsp; <code style="cursor:help" title="The transpose: rows become columns.">X.T</code> &nbsp;&nbsp; <code style="cursor:help" title="Matrix multiplication. For two vectors this is the dot product: multiply pairwise, then add.">A @ B</code> &nbsp;&nbsp; <code style="cursor:help" title="A column of ones, n long. Useful as the intercept column of a regression.">np.ones(n)</code> &nbsp;&nbsp; <code style="cursor:help" title="Glue 1-D arrays together side by side, as columns of a matrix.">np.column_stack([a, b])</code> &nbsp;&nbsp; <code style="cursor:help" title="The inverse: the matrix that undoes A.">np.linalg.inv(A)</code> &nbsp;&nbsp; <code style="cursor:help" title="Solve A x = b for x. Safer and faster than inverting.">np.linalg.solve(A, b)</code></p>
#
# <p style="line-height:2.1"><strong>pandas: one column</strong><br>
# <code style="cursor:help" title="A Series: values with a label on each one. Build it from a dictionary or a list.">pd.Series(data)</code> &nbsp;&nbsp; <code style="cursor:help" title="Look a value up by its label, like a dictionary.">s['AAPL']</code> &nbsp;&nbsp; <code style="cursor:help" title="Sort by value. Pass ascending=False for largest first.">s.sort_values()</code> &nbsp;&nbsp; <code style="cursor:help" title="A Series summarises itself, exactly like an array.">s.mean()</code></p>
#
# <p style="line-height:2.1"><strong>pandas: a table</strong><br>
# <code style="cursor:help" title="Read a CSV file into a DataFrame. parse_dates turns a text date column into real dates.">pd.read_csv(path, parse_dates=['date'])</code> &nbsp;&nbsp; <code style="cursor:help" title="The first n rows, 5 by default.">frame.head(n)</code> &nbsp;&nbsp; <code style="cursor:help" title="Rows and columns, as a pair of numbers.">frame.shape</code> &nbsp;&nbsp; <code style="cursor:help" title="What each column holds: dates, text, numbers.">frame.dtypes</code> &nbsp;&nbsp; <code style="cursor:help" title="The column names.">frame.columns</code></p>
#
# <p style="line-height:2.1"><strong>pandas: choosing what you want</strong><br>
# <code style="cursor:help" title="One column, as a Series.">frame['close']</code> &nbsp;&nbsp; <code style="cursor:help" title="Several columns, as a smaller table. Note the two sets of brackets.">frame[['date', 'close']]</code> &nbsp;&nbsp; <code style="cursor:help" title="Keep only the rows where the condition is True.">frame[frame['ticker'] == 'AAPL']</code> &nbsp;&nbsp; <code style="cursor:help" title="Take your own copy, so pandas knows you mean to change this selection and not the original.">.copy()</code> &nbsp;&nbsp; <code style="cursor:help" title="Rows by label. With a date index you can slice with dates.">frame.loc['2024']</code> &nbsp;&nbsp; <code style="cursor:help" title="Sort the rows by the values in a column.">frame.sort_values('ret')</code></p>
#
# <p style="line-height:2.1"><strong>pandas: new columns and groups</strong><br>
# <code style="cursor:help" title="Create a column by assigning to a name that does not exist yet.">frame['ret'] = ...</code> &nbsp;&nbsp; <code style="cursor:help" title="The percentage change from each row to the next. The first one is NaN.">frame['close'].pct_change()</code> &nbsp;&nbsp; <code style="cursor:help" title="Throw away the rows with no value (NaN).">s.dropna()</code> &nbsp;&nbsp; <code style="cursor:help" title="Split by the values in a column, do something inside each group, put the answers back together.">frame.groupby('ticker')</code> &nbsp;&nbsp; <code style="cursor:help" title="Several summaries at once, as a table.">g.agg(['mean', 'std'])</code> &nbsp;&nbsp; <code style="cursor:help" title="Reshape: one row per date, one column per ticker.">frame.pivot(index='date', columns='ticker', values='close')</code></p>
#
# <p style="line-height:2.1"><strong>Building tables out of what you have</strong><br>
# <code style="cursor:help" title="A Series straight from a dictionary: the keys become the labels.">pd.Series(a_dict)</code> &nbsp;&nbsp; <code style="cursor:help" title="A DataFrame from a dictionary of columns. Series are lined up on their labels for you.">pd.DataFrame({'vol': s1, 'ret': s2})</code> &nbsp;&nbsp; <code style="cursor:help" title="A DataFrame from a list of dictionaries: one row per dictionary. Useful when you build rows in a loop.">pd.DataFrame(list_of_dicts)</code> &nbsp;&nbsp; <code style="cursor:help" title="The plain numbers underneath, as a NumPy array, with the labels dropped.">frame.values</code></p>
#
# <p style="line-height:2.1"><strong>Still yours from Sessions 1 and 2</strong><br>
# <code style="cursor:help" title="Run the indented body once for every item.">for item in items:</code> &nbsp;&nbsp; <code style="cursor:help" title="Run the block only when the condition is True. elif adds further cases, else catches the rest.">if / elif / else</code> &nbsp;&nbsp; <code style="cursor:help" title="Define your own function. The indented body is what it does, and return hands a value back.">def name(x, rate=0.05):</code> &nbsp;&nbsp; <code style="cursor:help" title="Hand a value back to whoever called the function.">return value</code> &nbsp;&nbsp; <code style="cursor:help" title="An empty list, ready to be filled by a loop, and the method that fills it.">results = []  ·  results.append(x)</code> &nbsp;&nbsp; <code style="cursor:help" title="A dictionary: values stored under a name rather than a position.">{'AAPL': 0.36}</code> &nbsp;&nbsp; <code style="cursor:help" title="Show r as a percentage with 2 decimals.">f"{r:.2%}"</code></p>
#
# <p style="line-height:2.1"><strong>matplotlib</strong><br>
# <code style="cursor:help" title="Make a figure and one axes to draw on. figsize is in inches.">fig, ax = plt.subplots(figsize=(9, 3))</code> &nbsp;&nbsp; <code style="cursor:help" title="A line: something over time.">ax.plot(x, y)</code> &nbsp;&nbsp; <code style="cursor:help" title="Horizontal bars: comparing named things.">ax.barh(names, values)</code> &nbsp;&nbsp; <code style="cursor:help" title="A histogram: the shape of one variable.">ax.hist(values, bins=40)</code> &nbsp;&nbsp; <code style="cursor:help" title="A scatter: one thing against another.">ax.scatter(x, y)</code> &nbsp;&nbsp; <code style="cursor:help" title="The title. loc='left' puts it on the left, which reads better.">ax.set_title(text, loc='left')</code> &nbsp;&nbsp; <code style="cursor:help" title="Label the axes. Always say what the numbers are, and in what units.">ax.set_ylabel(text)</code> &nbsp;&nbsp; <code style="cursor:help" title="Show the legend. Needs label= on each line you drew.">ax.legend()</code> &nbsp;&nbsp; <code style="cursor:help" title="Save the figure to a file.">fig.savefig('name.png', dpi=200)</code></p>

# %% [markdown]
# **Formulas you will reach for**
#
# | what | formula |
# |:--|:--|
# | Simple return | $$r_i=\dfrac{p_i-p_{i-1}}{p_{i-1}}$$ |
# | Volatility (daily) | $$\sigma=\sqrt{\dfrac{1}{n}\sum_i (r_i-\bar{r})^2}$$ |
# | Annualised volatility | $$\sigma_{\text{year}}=\sigma\sqrt{252}$$ |
# | OLS estimate | $$\hat{\beta}=(X'X)^{-1}X'y$$ |

# %% [markdown]
# ---

# %% [markdown]
# ## ⚙️ Setup: run this first
#
# This imports the three packages and loads the price data. If you are in Google Colab, either upload `prices.csv` and `aapl_2024_closes.csv`, or set `REPO_RAW_URL` to the address your instructor gave you.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

CANDIDATE_DIRS = ["data", os.path.join("..", "data"), "."]
REPO_RAW_URL = "https://raw.githubusercontent.com/theill95/mlfin-2026/main/data/"   # used when the CSV files are not next to the notebook


def load_csv(filename, **kwargs):
    """Read one of the course CSV files, wherever it happens to be."""
    for folder in CANDIDATE_DIRS:
        path = os.path.join(folder, filename)
        if os.path.exists(path):
            return pd.read_csv(path, **kwargs)
    if REPO_RAW_URL is not None:
        return pd.read_csv(REPO_RAW_URL + filename, **kwargs)
    raise FileNotFoundError(
        f"Could not find {filename}. Run this notebook from the course folder, "
        f"upload the CSV into Colab, or set REPO_RAW_URL."
    )


# The whole universe: eleven stocks, 2015 to 2024, one row per stock per day
prices = load_csv("prices.csv", parse_dates=["date"])

# Apple's 2024 closes, as a plain NumPy array, for the array exercises
close24 = load_csv("aapl_2024_closes.csv")["close"].to_numpy()

# A single week of Apple closes, small enough to check by hand
week = np.array([183.56, 182.19, 179.87, 179.15, 183.48])

print("prices :", prices.shape, "rows x columns")
print("close24:", close24.shape[0], "trading days in 2024")
print("week   :", week)

# %% [markdown]
# ---

# %% [markdown]
# ## 🧮 A · Arrays
#
# An array is a list that does arithmetic on every element at once. Everything you learned about indexing and slicing lists still works.

# %% [markdown]
# ### A1 · From a list to an array  ★☆☆☆☆
#
# Turn the list `[10, 20, 30, 40]` into a NumPy array called `values`.

# %%
values = ...
values

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `np.array(...)` takes a list and gives back an array.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# values = np.array([10, 20, 30, 40])
# values
# ```
#
# It prints as `array([10, 20, 30, 40])`. It looks like a list, but it behaves quite differently.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A2 · The last three closes  ★☆☆☆☆
#
# Using the `week` array from the setup cell, take the **last three** closes into `last_three`.

# %%
last_three = ...
last_three

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Negative slicing from Session 1 still works: `week[-3:]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# last_three = week[-3:]
# last_three
# ```
#
# `array([179.87, 179.15, 183.48])`. Slicing an array is exactly like slicing a list.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A3 · Everything at once  ★☆☆☆☆
#
# Every price in `week` is in dollars. Convert the whole array to cents (multiply by 100) and store it as `cents`.

# %%
cents = ...
cents

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Multiply the array itself. There is no loop.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# cents = week * 100
# cents
# ```
#
# One short line does what took a loop and an empty list last session.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A4 · Two arrays, side by side  ★★☆☆☆
#
# Here are two arrays: an opening price and a closing price for four days. Compute the **change** on each day (close minus open) into `change`.

# %%
opens = np.array([100.0, 102.0, 101.5, 104.0])
closes = np.array([102.0, 101.5, 104.0, 103.5])

change = ...
change

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Subtract one array from the other. NumPy lines them up position by position.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# opens = np.array([100.0, 102.0, 101.5, 104.0])
# closes = np.array([102.0, 101.5, 104.0, 103.5])
#
# change = closes - opens
# change
# ```
#
# `array([ 2. , -0.5,  2.5, -0.5])`. Element by element, no loop in sight.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A5 · Lining up the day before  ★★★☆☆
#
# From `week`, build two arrays: `today` (every close from the second onwards) and `yesterday` (every close except the last).

# %%
today = ...
yesterday = ...

print(today)
print(yesterday)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `week[1:]` starts at the second element. `week[:-1]` stops before the last.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Both arrays end up four long, and `today[i]` is the day after `yesterday[i]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# today = week[1:]
# yesterday = week[:-1]
#
# print(today)
# print(yesterday)
# ```
#
# Two views of the same prices, offset by one day. This is the whole trick behind computing returns without a loop.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A6 · Every daily return, in one line  ★★★☆☆
#
# Now use those two views to compute all four daily returns from `week`, into `returns`.

# %%
returns = ...
returns

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The formula is (today minus yesterday) divided by yesterday.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Written out: `(week[1:] - week[:-1]) / week[:-1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns = (week[1:] - week[:-1]) / week[:-1]
# returns
# ```
#
# Four returns from five prices, the first being `-0.007463`. Last session this was a loop, a `range`, an empty list and an `.append`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A7 · The loop you no longer need  ★★☆☆☆  · revisits S2
#
# Build the same four returns from `week` the Session 2 way, with a loop and an empty list, then turn the result into an array. Compare it with `(week[1:] - week[:-1]) / week[:-1]`.

# %%
loop_returns = []
for i in range(1, len(week)):
    ...

loop_returns = np.array(loop_returns)
loop_returns

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Inside the loop, append `(week[i] - week[i - 1]) / week[i - 1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `np.array(a_list)` turns the finished list into an array, which is how most arrays start life.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# loop_returns = []
# for i in range(1, len(week)):
#     loop_returns.append((week[i] - week[i - 1]) / week[i - 1])
#
# loop_returns = np.array(loop_returns)
# loop_returns
# ```
#
# Identical to the one-line version. The loop is not wrong, and understanding it is why the one-liner makes sense to you. From here on, write the one-liner.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 📊 B · Summarising an array
#
# The things you wrote by hand in Session 2 are already methods on the array.

# %% [markdown]
# ### B1 · Four numbers about a year  ★☆☆☆☆
#
# `close24` holds Apple's closing price on every trading day of 2024. Print its mean, minimum and maximum.

# %%
print('mean:', ...)
print('min :', ...)
print('max :', ...)

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `close24.mean()`, and the same pattern for the other two.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# print('mean:', close24.mean())
# print('min :', close24.min())
# print('max :', close24.max())
# ```
#
# Apple averaged about $205.46 in 2024, between $163.36 and $257.38.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B2 · Volatility, the short way  ★★☆☆☆
#
# Compute Apple's 2024 **daily volatility**: the returns first, then their standard deviation.

# %%
returns24 = ...
vol = ...
vol

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The returns line is the same slicing formula as A6, on `close24`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Volatility is `returns24.std()`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
# vol = returns24.std()
# vol
# ```
#
# About `0.0141`, so roughly 1.41% on a typical day. That is the number your Session 2 case computed with two loops and a function.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B3 · In the units finance uses  ★★☆☆☆
#
# Turn that daily volatility into an **annualised** one by multiplying by the square root of 252.

# %%
returns24 = (close24[1:] - close24[:-1]) / close24[:-1]

annual_vol = ...
annual_vol

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `np.sqrt(252)` gives the square root you need.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
#
# annual_vol = returns24.std() * np.sqrt(252)
# annual_vol
# ```
#
# About `0.2238`, so roughly 22% a year. This is the figure you would see quoted.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B4 · How far it travelled  ★★☆☆☆
#
# Compute Apple's **total return** over 2024: from the first close of the year to the last.

# %%
total_return = ...
total_return

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The first close is `close24[0]` and the last is `close24[-1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# It is the same simple-return formula, applied to those two prices.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# total_return = (close24[-1] - close24[0]) / close24[0]
# total_return
# ```
#
# About `0.3556`, a gain of 35.6% over the year.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B5 · Putting returns on a common scale  ★★★☆☆
#
# **Standardise** Apple's 2024 returns: subtract the mean, then divide by the standard deviation. Check that the result has mean 0 and standard deviation 1.

# %%
returns24 = (close24[1:] - close24[:-1]) / close24[:-1]

standardised = ...

print('mean:', ...)
print('std :', ...)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The formula is $(r - \bar{r}) / \sigma$, and it works on the whole array at once.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `(returns24 - returns24.mean()) / returns24.std()`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
#
# standardised = (returns24 - returns24.mean()) / returns24.std()
#
# print('mean:', standardised.mean())
# print('std :', standardised.std())
# ```
#
# The mean comes out as something like `2e-17`, which is zero with a rounding residue, and the standard deviation is exactly 1. A standardised value says how many standard deviations from average a day was, so the largest here is about 5.
#
# This is worth remembering: nearly every model you meet later in the course wants its inputs standardised, because otherwise a variable measured in millions drowns out one measured in percent.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## ⚖️ C · Asking a question of every element
#
# Comparing an array to a number gives you an answer for each element, which you can then count or filter with. This replaces the `if` inside a loop.

# %% [markdown]
# ### C1 · True or false, one per day  ★☆☆☆☆
#
# Using `week_returns` below, produce the array of `True`/`False` saying whether each day was up.

# %%
week_returns = (week[1:] - week[:-1]) / week[:-1]

was_up = ...
was_up

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Compare the array to zero: `week_returns > 0`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# week_returns = (week[1:] - week[:-1]) / week[:-1]
#
# was_up = week_returns > 0
# was_up
# ```
#
# `array([False, False, False,  True])`. One answer per element, and no loop.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C2 · Counting the up days  ★★☆☆☆
#
# Count how many of Apple's 2024 days were **up days**, using `returns24`.

# %%
returns24 = (close24[1:] - close24[:-1]) / close24[:-1]

up_days = ...
up_days

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Make the True/False array first, then add it up.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `(returns24 > 0).sum()` counts the `True`s, because `True` counts as one.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
#
# up_days = (returns24 > 0).sum()
# up_days
# ```
#
# `142` up days out of 251. A little over half, which is what you would expect from a year the stock rose in.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C3 · Keeping only some of them  ★★☆☆☆
#
# Keep only the **negative** returns from `returns24`, into `down_moves`.

# %%
returns24 = (close24[1:] - close24[:-1]) / close24[:-1]

down_moves = ...
down_moves

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Put the condition inside the square brackets: `returns24[returns24 < 0]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
#
# down_moves = returns24[returns24 < 0]
# down_moves
# ```
#
# 108 numbers, all of them negative. You now have the down days on their own, ready to summarise.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C4 · How bad is a bad day?  ★★★☆☆
#
# Using only the down days, compute their **average** size. Then compare it to the average up day.

# %%
returns24 = (close24[1:] - close24[:-1]) / close24[:-1]

avg_down = ...
avg_up = ...

print('average down day:', avg_down)
print('average up day  :', avg_up)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Filter first, then take the mean of what is left.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `returns24[returns24 < 0].mean()`, and the mirror image for up days.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
#
# avg_down = returns24[returns24 < 0].mean()
# avg_up = returns24[returns24 > 0].mean()
#
# print('average down day:', avg_down)
# print('average up day  :', avg_up)
# ```
#
# About `-0.0105` against `0.0103`. The typical down day is a little larger than the typical up day, which is normal for stocks: there are simply more up days.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C5 · A share, not a count  ★★☆☆☆
#
# What **fraction** of Apple's 2024 days were up days? Do it without dividing anything yourself.

# %%
returns24 = (close24[1:] - close24[:-1]) / close24[:-1]

up_share = ...
up_share

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The average of an array of `True` and `False` is the share that are `True`, because `True` counts as 1 and `False` as 0.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `(returns24 > 0).mean()`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
#
# up_share = (returns24 > 0).mean()
# up_share
# ```
#
# About `0.566`, so 57% of days were up. `.sum()` on a condition counts, and `.mean()` on the same condition gives the share. You will use both constantly.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🧱 D · Matrices
#
# A matrix is a two-dimensional array: rows and columns. Everything a dataset or a model is made of.

# %% [markdown]
# ### D1 · Building one  ★☆☆☆☆
#
# Build this 3 by 2 matrix as `X`, and print its shape:
#
# ```text
# 1.0   0.5
# 1.0   1.5
# 1.0   2.5
# ```

# %%
X = ...
print(X)

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# A list of rows, each row a list: `np.array([[1.0, 0.5], [1.0, 1.5], [1.0, 2.5]])`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# X = np.array([[1.0, 0.5],
#               [1.0, 1.5],
#               [1.0, 2.5]])
# print(X)
# print(X.shape)
# ```
#
# `X.shape` is `(3, 2)`: three rows, two columns. Rows always come first.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### D2 · Reaching into it  ★★☆☆☆
#
# From the `X` below, pull out the element in row 1 and column 0, the whole second row, and the whole second column.

# %%
X = np.array([[1.0, 0.5],
              [1.0, 1.5],
              [1.0, 2.5]])

one = ...
row = ...
column = ...

print(one)
print(row)
print(column)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `X[row, column]`, and `:` means all of them.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The second row is `X[1, :]`. The second column is `X[:, 1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# X = np.array([[1.0, 0.5],
#               [1.0, 1.5],
#               [1.0, 2.5]])
#
# one = X[1, 0]
# row = X[1, :]
# column = X[:, 1]
#
# print(one)
# print(row)
# print(column)
# ```
#
# `1.0`, then `[1.  1.5]`, then `[0.5 1.5 2.5]`. Counting starts at zero in both directions.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### D3 · A portfolio return  ★★☆☆☆
#
# You hold 50% Apple, 30% Coca-Cola and 20% Nvidia. On one day they returned 1.2%, -0.4% and 3.1%. Compute the portfolio's return for that day.

# %%
weights = np.array([0.5, 0.3, 0.2])
returns = np.array([0.012, -0.004, 0.031])

portfolio_return = ...
portfolio_return

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Multiply pairwise and add up. That is the dot product.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `weights @ returns` does it in one step.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# weights = np.array([0.5, 0.3, 0.2])
# returns = np.array([0.012, -0.004, 0.031])
#
# portfolio_return = weights @ returns
# portfolio_return
# ```
#
# `0.011` exactly: `0.5*0.012 + 0.3*(-0.004) + 0.2*0.031`. A 1.1% day for the portfolio.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### D4 · Fitted values for a whole sample  ★★★☆☆
#
# With `X` (3 rows, 2 columns) and coefficients `b = [0.001, 1.2]`, compute the fitted value for every row at once.

# %%
X = np.array([[1.0, 0.012],
              [1.0, -0.004],
              [1.0, 0.008]])
b = np.array([0.001, 1.2])

fitted = ...
fitted

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `X @ b`. Three rows in, three numbers out.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# X = np.array([[1.0, 0.012],
#               [1.0, -0.004],
#               [1.0, 0.008]])
# b = np.array([0.001, 1.2])
#
# fitted = X @ b
# fitted
# ```
#
# `array([ 0.0154, -0.0038,  0.0106])`. This is a regression's prediction step for the whole sample, written once.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## ➗ E · Linear algebra
#
# The same maths as your econometrics course, one line per step.

# %% [markdown]
# ### E1 · Undoing a matrix  ★★☆☆☆
#
# Compute the inverse of `A`, then multiply it by `A` and look at what you get.

# %%
A = np.array([[4.0, 2.0],
              [1.0, 3.0]])

A_inv = ...
check = ...

print(A_inv)
print(check)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `np.linalg.inv(A)` gives the inverse.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Then multiply them with `@`, in either order.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# A = np.array([[4.0, 2.0],
#               [1.0, 3.0]])
#
# A_inv = np.linalg.inv(A)
# check = A_inv @ A
#
# print(A_inv)
# print(check)
# ```
#
# `check` is the identity: ones on the diagonal, zeros elsewhere. Some of the zeros print in scientific notation, as something like `-5.5e-17`. That is a rounding residue, not a real number. Read it as zero.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E2 · Solving a system  ★★☆☆☆
#
# Solve $Ax = b$ for $x$, with the `A` and `b` below. Use `np.linalg.solve`.

# %%
A = np.array([[4.0, 2.0],
              [1.0, 3.0]])
b = np.array([10.0, 10.0])

x = ...
x

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `np.linalg.solve(A, b)` takes the matrix first and the right-hand side second.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# A = np.array([[4.0, 2.0],
#               [1.0, 3.0]])
# b = np.array([10.0, 10.0])
#
# x = np.linalg.solve(A, b)
# x
# ```
#
# `array([1., 3.])`. Check it if you like: `A @ x` gives back `[10., 10.]`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E3 · OLS by hand, once  ★★★★★
#
# Estimate a regression of `y` on a constant and `x`, using the formula $\hat{\beta}=(X'X)^{-1}X'y$. Build the `X` matrix first: a column of ones, then `x`.

# %%
x = np.array([0.5, 1.5, 2.5, 3.5])
y = np.array([1.0, 2.0, 2.6, 3.8])

X = ...
beta = ...
beta

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `np.column_stack([np.ones(len(x)), x])` glues a column of ones onto `x`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Then `beta = np.linalg.solve(X.T @ X, X.T @ y)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# x = np.array([0.5, 1.5, 2.5, 3.5])
# y = np.array([1.0, 2.0, 2.6, 3.8])
#
# X = np.column_stack([np.ones(len(x)), x])
# beta = np.linalg.solve(X.T @ X, X.T @ y)
# beta
# ```
#
# `array([0.55, 0.9 ])`: an intercept of 0.55 and a slope of 0.90. The same answer your econometrics software would give.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E4 · What the model missed  ★★★☆☆
#
# Using the `beta` you just estimated, compute the **fitted values** and the **residuals** (actual minus fitted), and check that the residuals average out to about zero.

# %%
x = np.array([0.5, 1.5, 2.5, 3.5])
y = np.array([1.0, 2.0, 2.6, 3.8])
X = np.column_stack([np.ones(len(x)), x])
beta = np.linalg.solve(X.T @ X, X.T @ y)

fitted = ...
residuals = ...

print('fitted   :', fitted)
print('residuals:', residuals)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The fitted values are `X @ beta`, one per row.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The residuals are what is left over: `y - fitted`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# x = np.array([0.5, 1.5, 2.5, 3.5])
# y = np.array([1.0, 2.0, 2.6, 3.8])
# X = np.column_stack([np.ones(len(x)), x])
# beta = np.linalg.solve(X.T @ X, X.T @ y)
#
# fitted = X @ beta
# residuals = y - fitted
#
# print('fitted   :', fitted)
# print('residuals:', residuals)
# print('mean residual:', residuals.mean())
# ```
#
# The residuals are `[0.0, 0.1, -0.2, 0.1]` and their mean is zero to rounding. That is not luck: including the column of ones is exactly what forces it. Residuals are how every model in this course will be judged.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E5 · Two routes to the same beta  ★★★☆☆
#
# The lecture gave you two ways to solve $\mathbf{X}^{\top}\mathbf{X}\,\hat{\boldsymbol\beta}=\mathbf{X}^{\top}\mathbf{y}$: invert the matrix, or hand the whole system to `solve`.
#
# Compute the coefficients **both** ways and check that they agree.

# %%
x = np.array([0.5, 1.5, 2.5, 3.5])
y = np.array([1.0, 2.0, 2.6, 3.8])
X = np.column_stack([np.ones(len(x)), x])

by_inverse = ...
by_solve = ...

print('inverse:', by_inverse)
print('solve  :', by_solve)
print('agree  :', ...)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The first is the textbook formula: `np.linalg.inv(X.T @ X) @ X.T @ y`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The second skips the inverse: `np.linalg.solve(X.T @ X, X.T @ y)`. Compare them with `np.allclose(by_inverse, by_solve)`, which is the array version of 'equal to within rounding'.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# x = np.array([0.5, 1.5, 2.5, 3.5])
# y = np.array([1.0, 2.0, 2.6, 3.8])
# X = np.column_stack([np.ones(len(x)), x])
#
# by_inverse = np.linalg.inv(X.T @ X) @ X.T @ y
# by_solve = np.linalg.solve(X.T @ X, X.T @ y)
#
# print('inverse:', by_inverse)
# print('solve  :', by_solve)
# print('agree  :', np.allclose(by_inverse, by_solve))
# ```
#
# Both give the same two coefficients, and `np.allclose` says so. They are not identical to the last bit, which is why you compare with `allclose` rather than `==`.
#
# `solve` is the one to use in practice: it is faster, and it is more accurate when the columns are nearly redundant. Forming the inverse explicitly is something you do to learn the formula, not to run it.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🏷️ F · Series
#
# A Series is one column of values with a label on each one. Think of it as a dictionary and an array at the same time.

# %% [markdown]
# ### F1 · From a dictionary  ★☆☆☆☆
#
# Turn this dictionary of annualised volatilities into a Series called `vol`:
#
# ```python
# {'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235}
# ```

# %%
vol = ...
vol

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `pd.Series(...)` accepts a dictionary directly.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# vol = pd.Series({'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235})
# vol
# ```
#
# The tickers become the labels, and the numbers become the values.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### F2 · Looking one up  ★☆☆☆☆
#
# From the `vol` Series below, read out Nvidia's number.

# %%
vol = pd.Series({'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235})

nvda_vol = ...
nvda_vol

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Square brackets and the label, just like a dictionary.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# vol = pd.Series({'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235})
#
# nvda_vol = vol['NVDA']
# nvda_vol
# ```
#
# `0.525`. Reading by name is one of the two things a Series does.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### F3 · Maths on the whole thing  ★★☆☆☆
#
# Those are annual figures. Convert the whole Series back to **daily** volatility by dividing by the square root of 252.

# %%
vol = pd.Series({'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235})

daily_vol = ...
daily_vol

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Divide the Series itself, exactly as you would an array. The labels come along.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# vol = pd.Series({'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235})
#
# daily_vol = vol / np.sqrt(252)
# daily_vol
# ```
#
# Every value is divided and every label is kept. That combination is the whole reason pandas exists.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### F4 · Riskiest first  ★★☆☆☆
#
# Sort the `vol` Series so the **largest** volatility comes first.

# %%
vol = pd.Series({'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235})

ranked = ...
ranked

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `.sort_values()` sorts smallest first. There is an argument to reverse it.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# vol = pd.Series({'AAPL': 0.227, 'KO': 0.128, 'NVDA': 0.525, 'JPM': 0.235})
#
# ranked = vol.sort_values(ascending=False)
# ranked
# ```
#
# NVDA, JPM, AAPL, KO. `ascending=False` is the argument, and it is exactly the kind of detail you look up rather than memorise.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 📄 G · A real table
#
# `prices` is the whole universe: eleven stocks, every trading day from 2015 to 2024, one row per stock per day.

# %% [markdown]
# ### G1 · First look  ★☆☆☆☆
#
# Print the shape of `prices`, and show its first five rows.

# %%
print(...)

prices.head()

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `prices.shape` gives the rows and columns. `.head()` shows the top five rows.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# print(prices.shape)
#
# prices.head()
# ```
#
# `(27676, 4)`: 27,676 rows and 4 columns. Always look before you compute.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G2 · What is in each column  ★☆☆☆☆
#
# Show what type of data each column of `prices` holds.

# %%
kinds = ...
kinds

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `prices.dtypes`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# kinds = prices.dtypes
# kinds
# ```
#
# `date` is a real date, `ticker` is text (`object`), `close` is a float and `volume` is a whole number. A price column that arrived as text is a common and silent bug, and this is how you catch it.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G3 · One column  ★☆☆☆☆
#
# Take the `close` column of `prices` on its own, into `closes`.

# %%
closes = ...
closes

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# A column name in square brackets: `prices['close']`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = prices['close']
# closes.head()
# ```
#
# One name gives back a Series: that column, with the row labels kept.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G4 · Two columns  ★★☆☆☆
#
# Take just the `date` and `close` columns, into `small`.

# %%
small = ...
small

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# A **list** of names inside the brackets, so there are two sets of brackets.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `prices[['date', 'close']]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# small = prices[['date', 'close']]
# small.head()
# ```
#
# A list of names gives back a smaller DataFrame, not a Series. That is why the brackets are doubled.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🔎 H · Choosing rows, adding columns
#
# Filtering a table is the same idea as a mask on an array, done to 27,676 rows at once.

# %% [markdown]
# ### H1 · One stock  ★★☆☆☆
#
# Keep only the Coca-Cola rows of `prices`, into `ko`.

# %%
ko = ...
ko

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The condition is `prices['ticker'] == 'KO'`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Put that condition inside `prices[...]`, and use `.shape` for the row count.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# ko = prices[prices['ticker'] == 'KO']
# print(ko.shape)
#
# ko.head()
# ```
#
# `(2516, 4)`: one row per trading day over ten years, for one stock.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H2 · The warning nobody reads  ★★★☆☆
#
# ⚠️ **Run the cell below.** It keeps the Apple rows, then adds a column to them, and pandas prints a `SettingWithCopyWarning`.
#
# The warning is telling you something real: pandas cannot tell whether `aapl` is its own table or a view onto `prices`, so it does not know whether you meant to change `prices` as well. Repair it with the one method from the lecture that settles the question, then confirm `prices` was left alone.

# %%
aapl = prices[prices['ticker'] == 'AAPL']
aapl['expensive'] = aapl['close'] > 200

fixed = ...

print('columns in prices:', list(prices.columns))

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The lecture's answer was `.copy()`: take your own table, then nobody has to guess.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `fixed = prices[prices['ticker'] == 'AAPL'].copy()`, and then assign the column on `fixed`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# aapl = prices[prices['ticker'] == 'AAPL'].copy()
# aapl['expensive'] = aapl['close'] > 200
#
# fixed = aapl
#
# print('columns in prices:', list(prices.columns))
# print('expensive days:', int(fixed['expensive'].sum()))
# ```
#
# `141` days out of 2,516, and `prices` still has its original four columns.
#
# This warning is the most ignored message in pandas, and ignoring it is how people end up with a column that silently did not get written, or one that got written to the wrong table. `.copy()` costs nothing and ends the ambiguity.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H3 · A returns column  ★★☆☆☆
#
# Take the Microsoft rows, then add a `ret` column holding the daily return.

# %%
msft = prices[prices['ticker'] == 'MSFT'].copy()

msft['ret'] = ...
msft[['date', 'close', 'ret']].head()

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `msft['close'].pct_change()` is the daily return of that column.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# msft = prices[prices['ticker'] == 'MSFT'].copy()
#
# msft['ret'] = msft['close'].pct_change()
# msft[['date', 'close', 'ret']].head()
# ```
#
# The first row is `NaN`, because the first day has no day before it. The `.copy()` is what stops pandas warning you that it cannot tell whether you also meant to change `prices`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H4 · Volatility from a table  ★★☆☆☆
#
# Using that `ret` column, compute Microsoft's daily volatility over the whole period.

# %%
msft = prices[prices['ticker'] == 'MSFT'].copy()
msft['ret'] = msft['close'].pct_change()

vol = ...
vol

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `.std()` on the column. It skips the `NaN` for you.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# msft = prices[prices['ticker'] == 'MSFT'].copy()
# msft['ret'] = msft['close'].pct_change()
#
# vol = msft['ret'].std()
# vol
# ```
#
# About `0.0171`, so 1.71% on a typical day. You did not have to drop the `NaN` yourself: most summary methods ignore it.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H5 · The three worst days  ★★★☆☆
#
# Sort Apple's rows by return, smallest first, into `worst`. The three worst days and their dates should end up at the top.

# %%
aapl = prices[prices['ticker'] == 'AAPL'].copy()
aapl['ret'] = aapl['close'].pct_change()

worst = ...
worst

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `.sort_values('ret')` sorts the whole table by that column.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Smallest first is the default, so you do not need `ascending`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# aapl = prices[prices['ticker'] == 'AAPL'].copy()
# aapl['ret'] = aapl['close'].pct_change()
#
# worst = aapl.sort_values('ret')
# worst[['date', 'close', 'ret']].head(3)
# ```
#
# 16 March 2020 at about -12.9%, then 3 January 2019 and 12 March 2020. The first and third are the covid crash; the middle one is the day after Apple cut its revenue guidance.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H6 · A slice of time  ★★☆☆☆
#
# Keep only the rows of `prices` from 2023 onwards, into `recent`, and check how many rows that leaves.

# %%
recent = ...
recent

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `prices['date'] >= '2023-01-01'` is a condition on the date column, and it works because the quick setup parsed those dates properly.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Put it in brackets: `prices[prices['date'] >= '2023-01-01']`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# recent = prices[prices['date'] >= '2023-01-01']
# print(recent.shape)
# recent.head()
# ```
#
# 5,522 rows: 502 trading days for each of the eleven. Cutting a table by date is how you will separate the period a model learns from, from the period you test it on.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🧮 I · All eleven at once
#
# `groupby` splits the table by a column, does something inside each group, and puts the answers back together. It is the loop from Session 2, written once.

# %% [markdown]
# ### I1 · How many rows each  ★★☆☆☆
#
# Count how many rows `prices` holds for each ticker.

# %%
counts = ...
counts

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `prices.groupby('ticker').size()` counts the rows in each group.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# counts = prices.groupby('ticker').size()
# counts
# ```
#
# 2,516 for every one of the eleven, which is a good sign: no stock is missing days.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I2 · Average price per stock  ★★☆☆☆
#
# Compute the average closing price of each stock over the whole period.

# %%
avg_close = ...
avg_close

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Group by ticker, pick the `close` column, then `.mean()`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# avg_close = prices.groupby('ticker')['close'].mean()
# avg_close
# ```
#
# Eleven answers, each under its ticker. Note that these are not comparable across stocks: a share price depends on how many shares exist, not on how good the company is.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I3 · Eleven volatilities, all slightly wrong  ★★★★☆
#
# A colleague computed every stock's volatility with the cell below. It runs, it produces eleven sensible-looking numbers, and **every one of them is too high**. Walmart's comes out at 2.33% a day when the truth is 1.33%.
#
# The table is stacked: all of Apple's rows, then all of Disney's, and so on. Work out what that does to `pct_change`, then fix it.

# %%
prices['ret_wrong'] = prices['close'].pct_change()
wrong = prices.groupby('ticker')['ret_wrong'].std().sort_values(ascending=False)
print((wrong * 100).round(2).head(4))

vol = ...
vol

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Where does one stock's block of rows end and the next one begin? What does `pct_change` compute on that one row?
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Group **before** taking the change, so the calculation never steps across a boundary: `prices.groupby('ticker')['close'].pct_change()`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices['ret'] = prices.groupby('ticker')['close'].pct_change()
#
# vol = prices.groupby('ticker')['ret'].std().sort_values(ascending=False)
# vol
# ```
#
# Nvidia leads at about 3.06% a day, and the S&P 500 ETF is calmest at about 1.11%.
#
# **Ten rows were poisoning the whole table.** At each boundary the ungrouped `pct_change` computed a return from the last price of one company to the first price of the next, producing a fake move of tens of percent. Ten bad numbers out of 27,676 were enough to inflate Coca-Cola's volatility by 85%.
#
# Nothing errored, nothing looked odd, and the ranking even stayed plausible. This is the most common bug in applied pandas, and the only defence is to group before you compute anything that looks at a neighbouring row.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I4 · A small risk report  ★★★☆☆
#
# Produce a table with the mean, standard deviation, minimum and maximum daily return for every stock.

# %%
prices['ret'] = prices.groupby('ticker')['close'].pct_change()

report = ...
report

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `.agg(['mean', 'std', 'min', 'max'])` after the groupby gives all four at once.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices['ret'] = prices.groupby('ticker')['close'].pct_change()
#
# report = prices.groupby('ticker')['ret'].agg(['mean', 'std', 'min', 'max']).round(4)
# report
# ```
#
# One row per stock, four columns. That is a risk report, and it took one line.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I5 · One column per stock  ★★☆☆☆
#
# Reshape `prices` so that there is one row per date and one column per ticker, holding the closing price. Call it `wide`.

# %%
wide = ...
wide

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `prices.pivot(index='date', columns='ticker', values='close')`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# wide.tail(3)
# ```
#
# The tall shape is better for storing and grouping; this wide one is better for comparing stocks and for plotting.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 📈 J · Figures
#
# Every plot is the same three steps: make the axes, draw on them, then say what the reader is looking at.

# %% [markdown]
# ### J1 · A labelled line  ★☆☆☆☆
#
# Draw Apple's 2024 closing price. Give the plot a title and a y-axis label.

# %%
fig, ax = plt.subplots(figsize=(9, 3))
...
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `ax.plot(close24)` draws the line. Then `ax.set_title(...)` and `ax.set_ylabel(...)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Put the title on the left with `loc='left'`, which reads better on a slide or in a report.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# fig, ax = plt.subplots(figsize=(9, 3))
# ax.plot(close24)
# ax.set_title('Apple (AAPL) closing price, 2024', loc='left')
# ax.set_ylabel('price (USD)')
# plt.show()
# ```
#
# Without the title and the label this is just a wiggly line. The x-axis here is the day number, because `close24` is a plain array with no dates attached.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### J2 · Two lines and a legend  ★★☆☆☆
#
# Using `wide` below, draw Apple and Microsoft's 2024 prices on the same axes, with a legend.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
p24 = wide.loc['2024']

fig, ax = plt.subplots(figsize=(9, 3))
...
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Two `ax.plot(...)` calls, each with `label='AAPL'` or `label='MSFT'`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Then one `ax.legend()` at the end.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# p24 = wide.loc['2024']
#
# fig, ax = plt.subplots(figsize=(9, 3))
# ax.plot(p24.index, p24['AAPL'], label='AAPL')
# ax.plot(p24.index, p24['MSFT'], label='MSFT')
# ax.set_ylabel('price (USD)')
# ax.legend()
# plt.show()
# ```
#
# As soon as there is more than one line, the reader has to be told which is which. `label=` on each, then one `ax.legend()`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### J3 · Fix the figure  ★★★☆☆
#
# The figure below is drawn, and it is not publishable. Run it, then work through the lecture's checklist and repair the three faults:
#
# - the bars are in the order the tickers happen to appear, not in rank order
# - the horizontal axis is cut off at 0.008, which makes small differences look enormous
# - there is no title and no axis label, so a reader cannot tell what is being measured
#
# **Bars must start at zero.** That is the one rule on the checklist that is not a matter of taste.

# %%
prices['ret'] = prices.groupby('ticker')['close'].pct_change()
vol = prices.groupby('ticker')['ret'].std()

fig, ax = plt.subplots(figsize=(9, 3.5))
ax.barh(vol.index, vol.values)
ax.set_xlim(0.008, 0.032)
plt.show()

# your repaired version:
vol_sorted = ...

fig, ax = plt.subplots(figsize=(9, 3.5))
...
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `vol.sort_values()` puts the smallest at the bottom, which reads best on horizontal bars.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Drop the `set_xlim` entirely, then add `ax.set_title(..., loc='left')` and `ax.set_xlabel('daily volatility')`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices['ret'] = prices.groupby('ticker')['close'].pct_change()
# vol = prices.groupby('ticker')['ret'].std()
#
# vol_sorted = vol.sort_values()
#
# fig, ax = plt.subplots(figsize=(9, 3.5))
# ax.barh(vol_sorted.index, vol_sorted.values)
# ax.set_title('Daily volatility, 2015 to 2024', loc='left')
# ax.set_xlabel('daily volatility')
# plt.show()
# ```
#
# In the broken version Coca-Cola appears to have almost no risk at all, because its bar starts at the left edge of a truncated axis rather than at zero. The numbers never changed; only the axis did.
#
# A truncated axis on a **line** chart is often fine, since a line shows change. On bars it is a lie, because the length of the bar is the whole message.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### J4 · The shape of a year  ★★☆☆☆
#
# Draw a histogram of Apple's daily returns using `returns24`, with 40 bins and a title.

# %%
returns24 = (close24[1:] - close24[:-1]) / close24[:-1]

fig, ax = plt.subplots(figsize=(9, 3))
...
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `ax.hist(returns24, bins=40)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# returns24 = (close24[1:] - close24[:-1]) / close24[:-1]
#
# fig, ax = plt.subplots(figsize=(9, 3))
# ax.hist(returns24, bins=40)
# ax.set_title('Apple daily returns, 2024', loc='left')
# ax.set_xlabel('daily return')
# plt.show()
# ```
#
# Most days are small moves near zero, with a few large ones out at the sides. That shape is what volatility is measuring the width of.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### J5 · One thing against another  ★★☆☆☆
#
# Draw a scatter of Apple's daily returns against the market's (SPY), for 2024. Label both axes.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
r24 = wide.loc['2024'].pct_change().dropna()

fig, ax = plt.subplots(figsize=(5.5, 4))
...
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `ax.scatter(r24['SPY'], r24['AAPL'])`, with the market on the x-axis because that is the thing doing the explaining.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Then `ax.set_xlabel(...)` and `ax.set_ylabel(...)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# r24 = wide.loc['2024'].pct_change().dropna()
#
# fig, ax = plt.subplots(figsize=(5.5, 4))
# ax.scatter(r24['SPY'], r24['AAPL'], s=10, alpha=0.6)
# ax.set_xlabel('market return (SPY)')
# ax.set_ylabel('Apple return')
# ax.set_title('Apple against the market, 2024', loc='left')
# plt.show()
# ```
#
# An upward-sloping cloud. The slope of a line through it is Apple's **beta**, which you computed with `np.linalg.solve` in the lecture.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### J6 · Two panels, one story  ★★★☆☆
#
# The level and the change are different pictures and they belong side by side. Using `plt.subplots(1, 2, ...)`, draw Apple's 2024 **price** on the left and its daily **returns** on the right, each with its own title.
#
# `plt.subplots(1, 2)` hands back an array of two axes, so you draw on `axes[0]` and `axes[1]` instead of on `ax`.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
p24 = wide.loc['2024', 'AAPL']
r24 = p24.pct_change().dropna()

fig, axes = plt.subplots(1, 2, figsize=(11, 3))
...
fig.tight_layout()
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `axes[0].plot(p24.index, p24.values)` and `axes[1].plot(r24.index, r24.values)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Give each one `set_title(..., loc='left')`, and the left panel a `set_ylabel('USD')`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# p24 = wide.loc['2024', 'AAPL']
# r24 = p24.pct_change().dropna()
#
# fig, axes = plt.subplots(1, 2, figsize=(11, 3))
# axes[0].plot(p24.index, p24.values)
# axes[0].set_title('Apple price, 2024', loc='left')
# axes[0].set_ylabel('USD')
# axes[1].plot(r24.index, r24.values, linewidth=0.8)
# axes[1].set_title('Apple daily returns, 2024', loc='left')
# fig.tight_layout()
# plt.show()
# ```
#
# The left panel wanders upward and never comes back. The right one hovers around zero all year. Same data, and only the right-hand panel has a mean and a spread worth quoting.
#
# `tight_layout` stops the two panels overlapping their labels, and you will want it on almost every multi-panel figure you draw.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🔍 K · Looking it up
#
# Everything so far came off the toolkit card. Real work does not. These three ask for functions this course never showed you, which you find the same way a professional does: hover the name in VS Code, or call `help()` on it.
#
# > Both work with no internet, because the text ships inside the package. That matters at the exam.

# %% [markdown]
# ### K1 · How many rows does head show?  ★★☆☆☆
#
# `head()` showed five rows every time. Find out how to ask for a different number, then show the first **three** rows of `prices`.

# %%
help(pd.DataFrame.head)

first_three = ...
first_three

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Read the first line that `help` prints. There is one argument, and it has a default.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# help(pd.DataFrame.head)     # head(self, n: 'int' = 5)
#
# first_three = prices.head(3)
# first_three
# ```
#
# The argument is `n`, and its default is 5. That is why you got five rows without asking. `prices.head(3)` or `prices.head(n=3)` both work.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### K2 · A function nobody taught you  ★★★☆☆
#
# pandas has a method that gives you count, mean, standard deviation and the quartiles of a column in one go. It is called `describe`. Use `help` to see what it does, then run it on Apple's closing prices.

# %%
help(pd.Series.describe)

summary = ...
summary

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `prices[prices['ticker'] == 'AAPL']['close']` gets the column you want.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Then just call `.describe()` on it.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# help(pd.Series.describe)
#
# aapl_close = prices[prices['ticker'] == 'AAPL']['close']
# summary = aapl_close.describe()
# summary
# ```
#
# Eight numbers, including the median (shown as `50%`). Useful for a first look at any column, and you now know how to find out what any of the others do.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### K3 · Finding the largest values  ★★★☆☆
#
# You want the three most volatile stocks, largest first. You could sort and take the top three, but pandas has a method that does exactly this in one call. Its name begins with `nl`. Find it with `dir`, read it with `help`, then use it.

# %%
prices['ret'] = prices.groupby('ticker')['close'].pct_change()
vol = prices.groupby('ticker')['ret'].std()

print([name for name in dir(vol) if name.startswith('nl')])

top3 = ...
top3

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `dir(vol)` lists everything a Series can do. The filter narrows it to the name you want.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# It is `nlargest`, and it takes the number you want: `vol.nlargest(3)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices['ret'] = prices.groupby('ticker')['close'].pct_change()
# vol = prices.groupby('ticker')['ret'].std()
#
# print([name for name in dir(vol) if name.startswith('nl')])
#
# top3 = vol.nlargest(3)
# top3
# ```
#
# NVDA, AAPL and DIS. This is the whole skill: you knew what you wanted, you did not know the name, and you found it without leaving the notebook.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### K4 · Yesterday, next to today  ★★★☆☆
#
# You want each day's return sitting next to the **previous** day's, in the same row. pandas has a method that slides a column down by one. Find it with `dir`, then build a small table with both columns.

# %%
aapl = prices[prices['ticker'] == 'AAPL'].copy()
aapl['ret'] = aapl['close'].pct_change()

print([name for name in dir(aapl['ret']) if 'shif' in name])

aapl['ret_yesterday'] = ...
aapl[['date', 'ret', 'ret_yesterday']].head()

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The method is `shift`. `help(pd.Series.shift)` shows it takes how many places to move by.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `aapl['ret'].shift(1)` puts each value one row further down, so row *i* holds the value from row *i - 1*.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# aapl = prices[prices['ticker'] == 'AAPL'].copy()
# aapl['ret'] = aapl['close'].pct_change()
#
# aapl['ret_yesterday'] = aapl['ret'].shift(1)
# aapl[['date', 'ret', 'ret_yesterday']].head()
# ```
#
# The first two rows are `NaN`, because there is no yesterday for the first day and no return at all for the day before that.
#
# This is the single most important move in time-series machine learning. To predict today from the past you must line the past up next to today, and `shift` is how. Do it the wrong way and you have used tomorrow's information to predict today, which flatters your model and means nothing.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### K5 · Volatility that changes over time  ★★★☆☆
#
# A single volatility for a whole year hides the calm months and the wild ones. pandas can compute a statistic over a sliding window of rows. The method is called `rolling`. Use it to get Apple's volatility over the last 20 trading days, at every point in 2024.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')

rolling_vol = ...
rolling_vol

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `help(pd.Series.rolling)`. You call `.rolling(20)` and then the statistic you want, exactly as you would on the whole column.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `wide['AAPL'].pct_change().rolling(20).std() * np.sqrt(252)` gives an annualised figure for every day, using the 20 days up to it.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
#
# rolling_vol = wide['AAPL'].pct_change().rolling(20).std() * np.sqrt(252)
# rolling_vol.loc['2024'].tail()
# ```
#
# The first 19 values are `NaN`, because a 20-day window needs 20 days. Across 2024 the number runs from about 10% to about 35%, so the single 22% figure you computed earlier is an average of very different months.
#
# `rolling` is where most financial features come from: today's volatility, today's average, today's momentum. Session 4 calls these **features**.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🔁 L · The tools you already had
#
# Packages did not replace loops, functions, `if` and dictionaries. They replaced the *tedious* uses of them. These exercises put the two sessions together, because that combination is what real analysis code looks like.

# %% [markdown]
# ### L1 · A function that takes a Series  ★★☆☆☆  · revisits S2
#
# Write a function `annualise(daily_vol)` that turns a daily volatility into an annual one, and use it on the whole Series below in one call.

# %%
vol = pd.Series({'AAPL': 0.0141, 'KO': 0.0080, 'NVDA': 0.0331})

def annualise(daily_vol):
    ...

annualise(vol)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The body is one `return` line: multiply by `np.sqrt(252)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Because the multiplication works on a whole Series, the same function works for one number and for eleven.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# vol = pd.Series({'AAPL': 0.0141, 'KO': 0.0080, 'NVDA': 0.0331})
#
# def annualise(daily_vol):
#     """Turn a daily volatility into an annual one."""
#     return daily_vol * np.sqrt(252)
#
# annualise(vol)
# ```
#
# A function you wrote in Session 2 style, now doing eleven numbers at a time because pandas passes the whole Series through the arithmetic. Give it a docstring and your editor will show it when you hover the name.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L2 · A function with a default  ★★☆☆☆  · revisits S2
#
# Write `volatility(prices_series, periods=252)` that takes a Series of prices and returns its annualised volatility. Call it once with the default and once for a monthly figure (`periods=21`).

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')

def volatility(prices_series, periods=252):
    ...

print('annual :', volatility(wide['KO']))
print('monthly:', volatility(wide['KO'], periods=21))

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Inside: `.pct_change()`, then `.std()`, then multiply by `np.sqrt(periods)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `return prices_series.pct_change().std() * np.sqrt(periods)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
#
# def volatility(prices_series, periods=252):
#     """Annualised volatility of a price series."""
#     return prices_series.pct_change().std() * np.sqrt(periods)
#
# print('annual :', volatility(wide['KO']))
# print('monthly:', volatility(wide['KO'], periods=21))
# ```
#
# About `0.178` a year and `0.051` a month. The default argument from Session 2 earns its keep here: one function, two questions, no copy of the formula.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L3 · A loop over stocks, a dictionary of answers  ★★★☆☆  · revisits S2
#
# Using the `volatility` function below, loop over three tickers and collect their volatilities in a **dictionary** keyed by ticker.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')

def volatility(prices_series, periods=252):
    return prices_series.pct_change().std() * np.sqrt(periods)

tickers = ['AAPL', 'KO', 'NVDA']
vols = {}
for ticker in tickers:
    ...

vols

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `wide[ticker]` is that stock's price column.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Inside the loop: `vols[ticker] = volatility(wide[ticker])`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
#
# def volatility(prices_series, periods=252):
#     return prices_series.pct_change().std() * np.sqrt(periods)
#
# tickers = ['AAPL', 'KO', 'NVDA']
# vols = {}
# for ticker in tickers:
#     vols[ticker] = volatility(wide[ticker])
#
# vols
# ```
#
# Every idea in that cell came from Session 2: a loop, a function, a dictionary. Only the thing inside the function is new.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L4 · From a dictionary back to pandas  ★★☆☆☆  · revisits S2
#
# Turn the dictionary you just built into a **Series**, sort it riskiest first, and compare it with what `groupby` gives for the same three stocks.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
vols = {t: wide[t].pct_change().std() * np.sqrt(252) for t in ['AAPL', 'KO', 'NVDA']}

by_hand = ...
by_hand

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `pd.Series(vols)` takes the dictionary straight, then `.sort_values(ascending=False)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# vols = {t: wide[t].pct_change().std() * np.sqrt(252) for t in ['AAPL', 'KO', 'NVDA']}
#
# by_hand = pd.Series(vols).sort_values(ascending=False)
# by_hand
# ```
#
# The same three numbers `groupby` would give you. A dictionary is a Series waiting to happen, which is why Session 2 spent time on dictionaries.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L5 · Labelling with if, elif, else  ★★★☆☆  · revisits S2
#
# Write `risk_label(annual_vol)` that returns `'high'` above 0.30, `'medium'` above 0.18, and `'low'` otherwise. Then loop over every stock's 2024 volatility and collect the labels in a dictionary.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
vol24 = wide.loc['2024'].pct_change().std() * np.sqrt(252)

def risk_label(annual_vol):
    ...

labels = {}
for ticker in vol24.index:
    ...

labels

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The function is three branches: `if annual_vol > 0.30: return 'high'`, then `elif annual_vol > 0.18: return 'medium'`, then `else: return 'low'`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# In the loop, `labels[ticker] = risk_label(vol24[ticker])`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# vol24 = wide.loc['2024'].pct_change().std() * np.sqrt(252)
#
# def risk_label(annual_vol):
#     """Bucket an annualised volatility into high, medium or low."""
#     if annual_vol > 0.30:
#         return 'high'
#     elif annual_vol > 0.18:
#         return 'medium'
#     else:
#         return 'low'
#
# labels = {}
# for ticker in vol24.index:
#     labels[ticker] = risk_label(vol24[ticker])
#
# labels
# ```
#
# Nvidia alone is `high`; Disney, JPMorgan, Apple, Microsoft and Exxon are `medium`; the rest are `low`.
#
# You have just turned a number into a category, which is exactly what a **classification** problem predicts. Session 4 will call these labels a *target*.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L6 · One row per stock, built by a loop  ★★★★☆  · revisits S2
#
# Write `summarise(ticker)` that returns a **dictionary** with the ticker, its 2024 annualised volatility and its average daily return. Loop over three stocks, collect the dictionaries in a list, and hand the list to `pd.DataFrame`.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
r24 = wide.loc['2024'].pct_change()

def summarise(ticker):
    ...

rows = []
for ticker in ['AAPL', 'KO', 'NVDA']:
    ...

table = pd.DataFrame(rows)
table

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The function returns something like `{'ticker': ticker, 'vol': ..., 'mean_ret': ...}`, using `r24[ticker]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# In the loop, `rows.append(summarise(ticker))`. `pd.DataFrame` turns a list of dictionaries into a table, one row per dictionary.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# r24 = wide.loc['2024'].pct_change()
#
# def summarise(ticker):
#     """One row of a summary table, as a dictionary."""
#     return {
#         'ticker': ticker,
#         'vol': r24[ticker].std() * np.sqrt(252),
#         'mean_ret': r24[ticker].mean(),
#     }
#
# rows = []
# for ticker in ['AAPL', 'KO', 'NVDA']:
#     rows.append(summarise(ticker))
#
# table = pd.DataFrame(rows)
# table
# ```
#
# A list of dictionaries into `pd.DataFrame` is one of the most useful patterns there is, and it is how you will assemble a table of features one row at a time when the calculation is too awkward for `groupby`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L7 · The same answer, two ways  ★★★★☆  · revisits S2
#
# Compute every stock's 2024 annualised volatility twice: once with a loop over `wide.columns`, and once with pandas in a single expression. Then check that the two agree.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
p24 = wide.loc['2024']

loop_vols = {}
for ticker in p24.columns:
    ...

pandas_vols = ...
pandas_vols

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Inside the loop: `loop_vols[ticker] = p24[ticker].pct_change().std() * np.sqrt(252)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The one-liner is `p24.pct_change().std() * np.sqrt(252)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# p24 = wide.loc['2024']
#
# loop_vols = {}
# for ticker in p24.columns:
#     loop_vols[ticker] = p24[ticker].pct_change().std() * np.sqrt(252)
#
# pandas_vols = p24.pct_change().std() * np.sqrt(252)
#
# print(pd.Series(loop_vols).sort_index().round(6).equals(pandas_vols.sort_index().round(6)))
# ```
#
# `True`. Eleven lines of work and one line of work, agreeing to six decimals. Checking a fast method against a slow one you trust is a habit worth keeping, and it is how you will catch the mistakes that do not raise an error.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L8 · Report it the way a person reads it  ★★☆☆☆  · revisits S1
#
# A Series printed raw is for you. A report is for somebody else.
#
# Loop over the 2024 volatility ranking and print one line per stock: the ticker left-aligned in six characters, then the volatility as a percentage with one decimal, right-aligned in seven.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
vol24 = wide.loc['2024'].pct_change().std() * np.sqrt(252)
vol24 = vol24.sort_values(ascending=False)

for ticker in vol24.index:
    ...

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `vol24[ticker]` gets the value, exactly like a dictionary.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The Session 1 recipe with widths: `print(f"{ticker:<6}{vol24[ticker]:>7.1%}")`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# vol24 = wide.loc['2024'].pct_change().std() * np.sqrt(252)
# vol24 = vol24.sort_values(ascending=False)
#
# for ticker in vol24.index:
#     print(f"{ticker:<6}{vol24[ticker]:>7.1%}")
# ```
#
# Nvidia at 52.5% down to the S&P 500 ETF at 12.6%, in a column you could paste into an email. The f-string is Session 1, the loop is Session 2, the volatility is today. Nothing on this course gets thrown away.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L9 · How many names to fill the budget  ★★★☆☆  · revisits S2
#
# A desk adds stocks to a portfolio starting from the calmest, and stops as soon as the **sum** of their annualised volatilities passes 1.0. How many names does it take?
#
# This is a `while` loop, not a `for` loop: you do not know in advance how many steps it needs.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
vol24 = (wide.loc['2024'].pct_change().std() * np.sqrt(252)).sort_values()

budget = 0.0
n_names = 0

while False:          # <- replace with the right condition
    ...

print('names:', n_names, ' budget used:', round(budget, 3))

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The condition is on the budget: keep going `while budget <= 1.0`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Inside, add the next volatility, `vol24.iloc[n_names]`, then increase `n_names`. Order matters: read the value before you move the counter on.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# vol24 = (wide.loc['2024'].pct_change().std() * np.sqrt(252)).sort_values()
#
# budget = 0.0
# n_names = 0
#
# while budget <= 1.0:
#     budget = budget + vol24.iloc[n_names]
#     n_names = n_names + 1
#
# print('names:', n_names, ' budget used:', round(budget, 3))
# ```
#
# **Seven names**, using 1.121 of the budget. A `for` loop cannot express this directly, because the number of steps is the answer rather than the input.
#
# Note the danger you have just avoided: if every volatility were zero this loop would never stop. A `while` loop always needs something inside it that moves towards the exit.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L10 · The tickers arrive in a mess  ★★☆☆☆  · revisits S1
#
# A colleague sends a watchlist typed by hand. Before you can use it to select columns you have to clean it: strip the spaces, force uppercase, and keep only the ones that actually exist in `wide`.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
watchlist = ['  aapl ', 'KO', ' Msft', 'TSLA', 'nvda  ']

clean = []
for name in watchlist:
    ...

print('clean :', clean)
print('usable:', ...)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `name.strip().upper()` does both jobs, then append it.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# For the second list, keep the ones where `ticker in wide.columns`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# watchlist = ['  aapl ', 'KO', ' Msft', 'TSLA', 'nvda  ']
#
# clean = []
# for name in watchlist:
#     clean.append(name.strip().upper())
#
# usable = []
# for ticker in clean:
#     if ticker in wide.columns:
#         usable.append(ticker)
#
# print('clean :', clean)
# print('usable:', usable)
# ```
#
# Four of the five survive: Tesla is not in this universe. `.strip()` and `.upper()` are Session 1 string methods, and they are still the first thing that happens to any list of names somebody typed.
#
# Selecting `wide[watchlist]` without cleaning would have raised a `KeyError` on the very first entry.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### L11 · Retire the loop, and prove it  ★★★★☆  · revisits S2
#
# In Session 2 you counted a stock's up days with a loop and an `if`. pandas does it in one expression.
#
# Write **both**, for every stock at once: the loop version filling a dictionary, and the one-line version. Then check that they agree.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
rets = wide.pct_change().dropna()

by_loop = {}
for ticker in rets.columns:
    ...

by_pandas = ...

print(by_pandas)
print('agree:', ...)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Inside the loop, count with an accumulator exactly as in Session 2, then divide by `len(rets)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The whole thing at once is `(rets > 0).mean()`, because the mean of True and False is the share of Trues. Compare with `pd.Series(by_loop).sort_index().round(10).equals(by_pandas.sort_index().round(10))`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# rets = wide.pct_change().dropna()
#
# by_loop = {}
# for ticker in rets.columns:
#     up = 0
#     for r in rets[ticker]:
#         if r > 0:
#             up = up + 1
#     by_loop[ticker] = up / len(rets)
#
# by_pandas = (rets > 0).mean()
#
# print(by_pandas.round(4).to_dict())
# print('agree:', pd.Series(by_loop).sort_index().round(10).equals(by_pandas.sort_index().round(10)))
# ```
#
# `True`. Eleven nested loops over 2,515 days each, replaced by `(rets > 0).mean()`.
#
# This is the whole argument for Session 3 in one exercise. The loop is not wrong and it is not slow enough to matter here; it is just eleven times more code to read, and eleven more places to make the mistake you fixed in I3.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🧪 M · Groundwork for Session 4
#
# Next session is about what a model is actually asked to do. It has a vocabulary: an **observation** is one row, a **feature** is one column you are allowed to use, and the **target** is the column you are trying to predict. Everything below is ordinary pandas. The point is the shape you put the data into.

# %% [markdown]
# ### M1 · A table of features  ★★★☆☆
#
# Build a table with one row per stock and three columns describing its 2024: annualised volatility, average daily return, and the share of up days.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
r24 = wide.loc['2024'].pct_change()

vol = ...
mean_ret = ...
up_share = ...

features = ...
features

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Each one is a whole-table method: `r24.std() * np.sqrt(252)`, `r24.mean()`, and `(r24 > 0).mean()`. Each gives a Series labelled by ticker.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Then `pd.DataFrame({'vol': vol, 'mean_ret': mean_ret, 'up_share': up_share})` lines the three up on those labels for you.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# r24 = wide.loc['2024'].pct_change()
#
# vol = r24.std() * np.sqrt(252)
# mean_ret = r24.mean()
# up_share = (r24 > 0).mean()
#
# features = pd.DataFrame({'vol': vol, 'mean_ret': mean_ret, 'up_share': up_share})
# features.round(4)
# ```
#
# Eleven rows and three columns. **This shape is what every model in this course eats**: one row per observation, one column per feature, and the row labels saying which observation is which.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### M2 · Features and target  ★★★☆☆
#
# From that table, split off `y` (the volatility, the thing you would try to predict) and `X` (the two columns you would be allowed to use).

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
r24 = wide.loc['2024'].pct_change()
features = pd.DataFrame({'vol': r24.std() * np.sqrt(252), 'mean_ret': r24.mean(), 'up_share': (r24 > 0).mean()})

y = ...
X = ...

print('y:', y)
print('X:', X)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `y` is one column, so single brackets: `features['vol']`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `X` is several columns, so a list inside the brackets: `features[['mean_ret', 'up_share']]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# r24 = wide.loc['2024'].pct_change()
# features = pd.DataFrame({'vol': r24.std() * np.sqrt(252), 'mean_ret': r24.mean(), 'up_share': (r24 > 0).mean()})
#
# y = features['vol']
# X = features[['mean_ret', 'up_share']]
#
# print('y:', y.shape)
# print('X:', X.shape)
# ```
#
# `y` is `(11,)` and `X` is `(11, 2)`: eleven observations, two features. The names `X` and `y` are a convention you will see in every piece of machine learning code you ever read.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### M3 · From a table to a matrix  ★★☆☆☆
#
# Machine-learning libraries want plain numbers, not labels. Convert `X` to a NumPy array and check its shape.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
r24 = wide.loc['2024'].pct_change()
X = pd.DataFrame({'mean_ret': r24.mean(), 'up_share': (r24 > 0).mean()})

X_matrix = ...
X_matrix

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `.values` on a DataFrame gives the numbers underneath, as a 2-D NumPy array. `.to_numpy()` does the same thing.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# r24 = wide.loc['2024'].pct_change()
# X = pd.DataFrame({'mean_ret': r24.mean(), 'up_share': (r24 > 0).mean()})
#
# X_matrix = X.values
#
# print(type(X_matrix))
# print(X_matrix.shape)
# ```
#
# An `ndarray` of shape `(11, 2)`. This is the same `n` by `p` matrix from section D, and the same one that goes into $(X'X)^{-1}X'y$. The column names are gone, which is precisely why you keep the DataFrame around too.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### M4 · Putting the columns on the same scale  ★★★☆☆
#
# One feature is a daily return, around 0.001. The other is a share, around 0.5. Standardise every column of `X` so each has mean 0 and standard deviation 1.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
r24 = wide.loc['2024'].pct_change()
X = pd.DataFrame({'mean_ret': r24.mean(), 'up_share': (r24 > 0).mean()})

X_scaled = ...
X_scaled

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The same formula as B5, but on a whole table: subtract the mean and divide by the standard deviation.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `(X - X.mean()) / X.std()`. pandas applies it column by column, which is what you want.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# r24 = wide.loc['2024'].pct_change()
# X = pd.DataFrame({'mean_ret': r24.mean(), 'up_share': (r24 > 0).mean()})
#
# X_scaled = (X - X.mean()) / X.std()
# X_scaled.round(3)
# ```
#
# Both columns now run over roughly the same range, and a value of 2 means the same thing in either. Without this step, a method that measures distances would decide that `up_share` is the only variable that exists.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### M5 · Splitting on time, not at random  ★★★☆☆
#
# Split the price history into an **early** period (2015 to 2022) and a **late** one (2023 to 2024), and report how many trading days each contains.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')

early = ...
late = ...

print('early:', early)
print('late :', late)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The index is dates, so `.loc` slices with them: `wide.loc['2015':'2022']`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The second slice is `wide.loc['2023':'2024']`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
#
# early = wide.loc['2015':'2022']
# late = wide.loc['2023':'2024']
#
# print('early:', early.shape)
# print('late :', late.shape)
# ```
#
# 2,014 days against 502. Splitting **by time** rather than at random is not a detail: with prices, a randomly chosen test day would sit between two days you had already looked at, and any model would look far better than it is.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### M6 · Does the past tell you about the future?  ★★★★☆
#
# Compute the annualised volatility of every stock in the early period and again in the late one, put both in one table, and look at whether the ranking held.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')
early = wide.loc['2015':'2022']
late = wide.loc['2023':'2024']

early_vol = ...
late_vol = ...

comparison = ...
comparison

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Each one is `period.pct_change().std() * np.sqrt(252)`, which gives a Series labelled by ticker.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `pd.DataFrame({'early': early_vol, 'late': late_vol})` puts them side by side. Then sort by the early column to see whether the late one follows: `.sort_values('early', ascending=False)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
# early = wide.loc['2015':'2022']
# late = wide.loc['2023':'2024']
#
# early_vol = early.pct_change().std() * np.sqrt(252)
# late_vol = late.pct_change().std() * np.sqrt(252)
#
# comparison = pd.DataFrame({'early': early_vol, 'late': late_vol})
# comparison.sort_values('early', ascending=False).round(3)
# ```
#
# Roughly, yes. Nvidia is the most volatile in both periods and Coca-Cola and SPY are among the calmest in both. But it is far from exact: Apple falls from second riskiest to sixth, and Johnson & Johnson rises.
#
# That gap is the whole subject of the rest of this course. A quantity that carried over perfectly would need no model; one that carried over not at all could not be predicted. Volatility sits in between, which is what makes it worth forecasting.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 🧩 N · Putting it together
#
# Three questions that need more than one tool. This is what the case asks of you, so treat these as a rehearsal.

# %% [markdown]
# ### N1 · The ranking, annualised and plotted  ★★★☆☆
#
# Compute the **annualised** volatility of every stock over the whole period, sort it, and draw it as horizontal bars with a title and an x-axis label.

# %%
prices['ret'] = prices.groupby('ticker')['close'].pct_change()

annual_vol = ...

fig, ax = plt.subplots(figsize=(9, 3.5))
...
plt.show()

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Volatility per stock is `prices.groupby('ticker')['ret'].std()`. Annualising multiplies it by `np.sqrt(252)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Sort it with `.sort_values()` before plotting, then `ax.barh(annual_vol.index, annual_vol.values)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices['ret'] = prices.groupby('ticker')['close'].pct_change()
#
# annual_vol = (prices.groupby('ticker')['ret'].std() * np.sqrt(252)).sort_values()
#
# fig, ax = plt.subplots(figsize=(9, 3.5))
# ax.barh(annual_vol.index, annual_vol.values)
# ax.set_title('Annualised volatility, 2015 to 2024', loc='left')
# ax.set_xlabel('standard deviation of daily returns, annualised')
# plt.show()
# ```
#
# Nvidia at about 49% a year, the S&P 500 ETF at about 18%. The ETF being calmest is the point of diversification, in one bar.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### N2 · Which stock rose on the most days?  ★★★☆☆
#
# For every stock, count how many days its return was positive, and rank them.

# %%
prices['ret'] = prices.groupby('ticker')['close'].pct_change()

up_days = ...
up_days

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `prices['ret'] > 0` gives True/False for every row.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Make that a column, then group by ticker and `.sum()` it, because `True` counts as one.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices['ret'] = prices.groupby('ticker')['close'].pct_change()
# prices['was_up'] = prices['ret'] > 0
#
# up_days = prices.groupby('ticker')['was_up'].sum().sort_values(ascending=False)
# up_days
# ```
#
# The S&P 500 ETF comes top, just ahead of Nvidia, and every one of them is close to half. Rising on more days than not is a different question from rising a lot, which is why this ranking does not match the return ranking in L3.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### N3 · Ten years in one number  ★★☆☆☆
#
# For every stock, compute the **total return** over the whole period: last close against first close. Rank them, largest first.

# %%
wide = prices.pivot(index='date', columns='ticker', values='close')

total_return = ...
total_return

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `wide.iloc[0]` is the first row, one price per stock, and `wide.iloc[-1]` is the last. Both are Series, so you can do arithmetic with them directly.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `(wide.iloc[-1] - wide.iloc[0]) / wide.iloc[0]`, then sort it.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# wide = prices.pivot(index='date', columns='ticker', values='close')
#
# total_return = ((wide.iloc[-1] - wide.iloc[0]) / wide.iloc[0]).sort_values(ascending=False)
# total_return
# ```
#
# Nvidia returned about 27,700%, turning one dollar into 278. Note how differently the stocks rank here compared to the volatility ranking: risk and return are not the same question, and Session 4 is about telling them apart.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## ✅ Done
#
# You have now done, with three packages, everything you spent two sessions doing by hand: returns, volatility, counting, ranking, and looking at the result.
#
# Two sections are worth going back to. **K** is about looking things up: this notebook covered a few dozen functions, pandas alone has hundreds, and nobody carries them in their head. **M** is the shape of the data rather than the tools: one row per observation, one column per feature, a target you are trying to predict, and a split by time rather than at random. Session 4 is built on those four ideas, and you have now done all of them by hand.
#
# **Next:** open `session_03_case.ipynb` (*The Analyst's Notebook, Part 3*) and take the risk report from two stocks to all eleven.
#
# *Stuck for more than 15 minutes on anything? Ask a friend, ask an AI for a hint (not the answer), or email me at `jobo@econ.au.dk`.*
