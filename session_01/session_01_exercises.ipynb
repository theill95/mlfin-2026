# %% [markdown]
# # 📓 Session 1 · Exercises
# ### Beginning Python for Financial Data
#
# These exercises put the ideas from the lecture into practice. Programming is learned by doing, so most of the tasks ask you to write or complete a short piece of code yourself.
#
# Work through them at your own pace. They start easy and build up gradually.

# %% [markdown]
# ## How to use this notebook
#
# - Each exercise has a **task**, then a **code cell** for your work. Cells with `...` are blanks to fill in. Replace them with real code.
# - Stuck? Open the **💡 Hint**, but only after a genuine attempt. Open the **✅ Solution** to *check* yourself, not to skip the thinking.
# - Every cell you fill in runs cleanly even with the blanks still in place, so pressing **Run all** never floods you with errors. (A few cells in the **Errors** section are broken on purpose so you can see a real error message. They are clearly marked with ⚠️.)
# - No files, no internet. Every exercise stands on its own.
#
# **You are not expected to finish all of these.** Do what you can. The rest is here whenever you want to come back, and revising before the exam is a perfect time. Short on time? Read the hint, then the solution. A worked solution you genuinely understand is real learning too.

# %% [markdown]
# ### Difficulty
#
# | badge | what to expect |
# |:--|:--|
# | ★☆☆☆☆ | One step, straight from the lecture. You are checking that you can type it. |
# | ★★☆☆☆ | The same idea on new data, or two steps in a row. Nothing to decide. |
# | ★★★☆☆ | Combine two ideas, or adapt a pattern rather than copy it. |
# | ★★★★☆ | You choose the approach. Several steps, and something has to be worked out before you type. |
# | ★★★★★ | A genuine puzzle: an insight, or a constraint that rules out the obvious route. Always solvable with what you have. |
#
# The stars rate the work against **this** session. A three-star task in a later notebook assumes everything before it, so it is a bigger piece of work than a three-star task here, even though both sit in the middle of their own scale.
#
# Some exercises also carry a **revisits** tag. Those need something from an earlier session as well as today's material, and they are there on purpose: the skills are meant to accumulate, not to be handed in at the end of each week.

# %% [markdown]
# ## 🧰 Your toolkit for today
#
# Everything you need is on this card. No exercise asks for anything beyond it.
#
# > The names inside the brackets (`value`, `number`, `text`, `prices`, ...) are **placeholders**: you put your own value or variable there. Only the tool's name, the dots, the brackets and the quotes are fixed syntax. **Hover any tool** to see what it does and what goes in.
#
# <p style="line-height:2.1"><strong>Functions</strong> &nbsp; you call these by name<br>
# <code style="cursor:help" title="Show one or more values. Separate several with commas; each prints with a space between.">print(value)</code> &nbsp;&nbsp; <code style="cursor:help" title="Tell you what kind of value it is: int, float, str or bool.">type(value)</code> &nbsp;&nbsp; <code style="cursor:help" title="Round number to ndigits decimals. round(3.14159, 2) gives 3.14.">round(number, ndigits)</code> &nbsp;&nbsp; <code style="cursor:help" title="How many items are inside: characters in a string, elements in a list.">len(sequence)</code> &nbsp;&nbsp; <code style="cursor:help" title="The smallest of the values. Give it a list, or several values.">min(values)</code> &nbsp;&nbsp; <code style="cursor:help" title="The largest of the values. Give it a list, or several values.">max(values)</code> &nbsp;&nbsp; <code style="cursor:help" title="Add up every number in a list.">sum(numbers)</code></p>
#
# <p style="line-height:2.1"><strong>Methods</strong> &nbsp; these hang off a value with a dot<br>
# <code style="cursor:help" title="An UPPERCASE copy of the string. 'aapl'.upper() is 'AAPL'.">text.upper()</code> &nbsp;&nbsp; <code style="cursor:help" title="How many times part appears inside the string.">text.count(part)</code> &nbsp;&nbsp; <code style="cursor:help" title="Add value to the end of the list. It changes the list itself.">prices.append(value)</code> &nbsp;&nbsp; <code style="cursor:help" title="The position (counting from 0) where value first appears in the list.">prices.index(value)</code></p>
#
# <p style="line-height:2.1"><strong>Turn text into a number</strong><br>
# <code style="cursor:help" title="Turn a piece of text into a decimal number. float('52.40') is 52.4.">float(text)</code></p>
#
# <p style="line-height:2.1"><strong>Format inside an f-string</strong><br>
# <code style="cursor:help" title="Show price with 2 decimal places, e.g. 248.83.">f"{price:.2f}"</code> &nbsp;&nbsp; <code style="cursor:help" title="Show r as a percentage with 2 decimals. 0.0231 becomes 2.31%.">f"{r:.2%}"</code></p>

# %% [markdown]
# **Formulas you will reach for**
#
# | what | formula |
# |:--|:--|
# | Simple return | $r=\dfrac{p_1-p_0}{p_0}$ |
# | Compound growth | $FV = P\,(1+r)^{n}$ |
# | Average | $\bar{p}=\dfrac{\text{sum of values}}{\text{how many}}$ |
# | Range | $\text{range}=\max-\min$ |

# %% [markdown]
# ---

# %% [markdown]
# ## 📓 A · Notebooks & output
#
# *Get code to run, and show exactly what you want to see.*
#
# **Drills:** `print`, several outputs from one cell, the last-line rule.

# %% [markdown]
# ### A1 · Show the day's prices  ★☆☆☆☆
#
# A trading day has an **open**, a **high**, and a **low** price. They are stored below.
# Add three `print(...)` calls so that running the cell shows all three, each on its own line.

# %%
open_price = 189.30
high_price = 193.05
low_price = 188.60

# print each of the three prices below:
...

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `print(open_price)` shows one value. You need three such lines.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# open_price = 189.30
# high_price = 193.05
# low_price = 188.60
#
# print(open_price)
# print(high_price)
# print(low_price)
# ```
#
# Three lines in, three lines out. `print` is how you make a cell show more than just its final value.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A2 · Make them all appear  ★☆☆☆☆
#
# When you run the cell below, **only `78.0` appears**, because a cell shows just the value of its
# **last** line. Change the cell so that all three results are displayed.

# %%
12.0 + 18.0
30.0 + 25.0
40.0 + 38.0

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Wrap each line in `print(...)`. The last-line rule gives you only *one* automatic output; `print` gives you as many as you like.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# print(12.0 + 18.0)
# print(30.0 + 25.0)
# print(40.0 + 38.0)
# ```
#
# `30.0`, `55.0`, `78.0`. Without `print`, the first two results are computed and silently thrown away. Only the last line displays on its own.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### A3 · Label your output  ★☆☆☆☆
#
# A bare number on its own tells the reader nothing. Using a single `print(...)`, produce
# exactly this line:
#
# `Latest close: 248.83`

# %%
close = 248.83

# one print that produces:  Latest close: 248.83
...

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `print` can take several things separated by commas: `print("Latest close:", close)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# close = 248.83
#
# print("Latest close:", close)
# ```
#
# `print` accepts several arguments separated by commas and puts a space between them. Handy for labelling a value so future-you knows what it means.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you can run a cell and make it show precisely the output you intend.

# %% [markdown]
# ---

# %% [markdown]
# ## 🔢 B · Python as a calculator
#
# *Arithmetic, powers, and the order of operations.*
#
# **Drills:** `+ - * /`, `**`, parentheses, comments.

# %% [markdown]
# ### B1 · A quick invoice  ★☆☆☆☆
#
# You buy **120** shares at **45.50** each. Write one expression that computes the total cost,
# and add a `#` comment saying what it represents.

# %%
# total cost of the trade:
...

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Total cost is price times quantity. A comment is any text after a `#` on the line.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# 120 * 45.50    # 120 shares at 45.50 each = total cost
# ```
#
# `5460.0`. Anything after `#` is a note for humans; Python ignores it. Leave yourself comments, because next-week-you will be grateful.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B2 · The average price, done right  ★★☆☆☆
#
# Three desks quote a stock at **182.50**, **179.80**, and **184.20**. Compute the average of the
# three in a single expression.
#
# A trap lives here: because `/` runs before `+`, writing `a + b + c / 3` divides only the last
# price. Group correctly so all three are averaged.

# %%
q1 = 182.50
q2 = 179.80
q3 = 184.20

average = ...
average

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The three additions must all happen *before* the division. What forces that?
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Wrap the sum in parentheses: `(q1 + q2 + q3) / 3`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# q1 = 182.50
# q2 = 179.80
# q3 = 184.20
#
# average = (q1 + q2 + q3) / 3
# average
# ```
#
# `182.16666666666666`. Without the parentheses you would get `423.7`, a silently wrong answer. Add parentheses whenever the order of operations matters.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B3 · Compound growth  ★★☆☆☆
#
# Money left to grow at a fixed rate follows
#
# $$FV = P\,(1+r)^{n}$$
#
# where $P$ is the amount invested, $r$ the yearly rate, and $n$ the number of years.
# Invest **2000** at **6%** for **8** years, and complete the formula.

# %%
principal = 2000
rate = 0.06
years = 8

future_value = ...
future_value

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Recall `1000 * (1 + 0.04) ** 5` from the lecture. Same shape, new numbers.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `future_value = principal * (1 + rate) ** years`
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# principal = 2000
# rate = 0.06
# years = 8
#
# future_value = principal * (1 + rate) ** years
# future_value
# ```
#
# `3187.6961490616845`. Round it with `round(future_value, 2)` to get **3187.7**. The `**` operator is compounding: repeated multiplication, written once.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B4 · How many times your money?  ★★★☆☆
#
# Reuse the compound-growth formula for **5000** at **3.5%** over **12** years. Then also compute
# the **growth multiple** $(1+r)^{n}$, which is how many times the original the investment became.

# %%
principal = 5000
rate = 0.035
years = 12

future_value = ...
multiple = ...
print(future_value, multiple)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `future_value` is the B3 formula with these numbers.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `multiple = (1 + rate) ** years`, the same power term without the principal.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# principal = 5000
# rate = 0.035
# years = 12
#
# future_value = principal * (1 + rate) ** years
# multiple = (1 + rate) ** years
# print(future_value, multiple)
# ```
#
# `7555.3432867318015` and `1.5110686573463603`. The money grows about **1.51×**. Notice the formula never changed, only the inputs. Reusing a stored value instead of retyping it is what variables are for.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B5 · Up 4%, then down 3%  ★★☆☆☆
#
# A stock at **100** rises **4%** one week, then falls **3%** the next. Write one expression for its
# final price by multiplying by the two growth factors in turn.

# %%
# start at 100, then +4%, then -3%:
...

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# A +4% move multiplies by `1.04`; a -3% move multiplies by `0.97`. Chain them: `100 * 1.04 * 0.97`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# 100 * 1.04 * 0.97
# ```
#
# `100.88`. Up 4% then down 3% does **not** return to 100, because the second move acts on a bigger base. A small fact with large consequences for returns.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### B6 · What is it worth today?  ★★★☆☆
#
# A payment of **50000** arrives in **10** years. With money earning **5%** a year, its value
# *today* (its present value) is given by the compound-growth formula rearranged for you:
#
# $$PV = \dfrac{FV}{(1+r)^{n}}$$
#
# Translate that formula into code.

# %%
future_payment = 50000
rate = 0.05
years = 10

present_value = ...
present_value

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Read the formula straight across: divide `future_payment` by `(1 + rate) ** years`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# future_payment = 50000
# rate = 0.05
# years = 10
#
# present_value = future_payment / (1 + rate) ** years
# present_value
# ```
#
# `30695.66267703796`, about **30695.66**. This is *discounting*, one of the most-used ideas in finance, and it is the same `**` you already know, just dividing instead of multiplying.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you can turn a written formula into working arithmetic and keep the order of operations honest.

# %% [markdown]
# ---

# %% [markdown]
# ## 🏷️ C · Variables
#
# *Give a value a name so you can reuse it, update it, and read your own code later.*
#
# **Drills:** assignment, reuse, overwriting, naming rules.

# %% [markdown]
# ### C1 · Name a holding  ★☆☆☆☆
#
# Store a price of **189.50** and a quantity of **30** shares in well-named variables, then compute
# the holding's value from those names (not from the raw numbers).

# %%
price = ...
shares = ...
holding_value = ...
holding_value

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Three lines: assign `price`, assign `shares`, then multiply the two names.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price = 189.50
# shares = 30
# holding_value = price * shares
# holding_value
# ```
#
# `5685.0`. Once a value has a name, you write the name and never retype the number. Change `price` on one line and everything downstream updates.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C2 · Reuse what you built  ★★☆☆☆
#
# Continuing from a holding value, a position grows **10%**. Using the variable you already have
# (not the number), compute the new value.

# %%
price = 189.50
shares = 30
holding_value = price * shares

new_value = ...
new_value

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Multiply the existing `holding_value` by `1.10`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price = 189.50
# shares = 30
# holding_value = price * shares
#
# new_value = holding_value * 1.10
# new_value
# ```
#
# `6253.500000000001`. Building new results out of earlier ones, rather than one giant expression, is what keeps real analysis readable.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C3 · Overwrite, on purpose  ★★☆☆☆
#
# A price of **100** rises **2%** two days running. Model it with the *same* variable, reassigned each
# day. Read `price = price * 1.02` from the right: take the current price, grow it, store it back.

# %%
price = 100.0

# day 1: grow price by 2%
...
# day 2: grow price by 2% again
...
price

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Write `price = price * 1.02` twice. The name on the left is updated to the value computed on the right.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price = 100.0
#
# price = price * 1.02
# price = price * 1.02
# price
# ```
#
# `104.04`. A variable can appear on both sides of `=`. The right side is computed first with the *old* value, then the result replaces it.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C4 · Fix the illegal names  ★★☆☆☆
#
# Two names below are illegal Python. The rules: a name may use only letters, digits and
# underscores, **may not start with a digit**, and **may not contain a space**. Give each value a
# legal, readable name and print both.
#
# ```python
# 2015_return = 0.05      # starts with a digit
# share price = 45.50     # contains a space
# ```

# %%
# choose legal, readable names for these two values:
a = 0.05      # rename 'a'
b = 45.50     # rename 'b'
print(a, b)

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# For example `return_2015` and `share_price`. Underscores stand in for the spaces you are not allowed.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# return_2015 = 0.05
# share_price = 45.50
# print(return_2015, share_price)
# ```
#
# `0.05 45.5`. `2015_return` breaks the no-leading-digit rule; `share price` breaks the no-spaces rule. Good names read like English and cost nothing.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### C5 · The swap  ★★★☆☆
#
# `morning` and `evening` hold two prices. Swap their values, so afterwards `morning` holds what
# `evening` did and vice versa, using only assignment (no lists, no tricks you have not seen).

# %%
morning = 10.0
evening = 12.5

# swap them, so morning becomes 12.5 and evening becomes 10.0
...

print(morning, evening)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# If you write `morning = evening` first, the old `morning` is gone forever. You need somewhere to *park* it first.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Use a third variable: `temp = morning`, then `morning = evening`, then `evening = temp`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# morning = 10.0
# evening = 12.5
#
# temp = morning
# morning = evening
# evening = temp
#
# print(morning, evening)
# ```
#
# `12.5 10.0`. A temporary variable holds one value while the other is moved. It works because `=` stores a value; it does not create a link between the two names.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you can name values, reuse and update them, and name them well.

# %% [markdown]
# ---

# %% [markdown]
# ## 🧠 D · The notebook's memory
#
# *A notebook remembers what earlier cells defined, and only what has actually run.*
#
# **Drills:** using a name before it exists, execution order.

# %% [markdown]
# ### D1 · Nothing there yet  ★★☆☆☆
#
# ⚠️ **Run the cell below first.** On a fresh notebook it fails, because it reads `balance` before
# anything was stored under that name. Read the error, then fix it underneath: give `balance` a
# starting value of **1000**, then add 100, then show it.

# %%
balance = balance + 100

# %% [markdown]
# *Your fix:*

# %%
# make this run cleanly on a fresh notebook:
...

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The failing line uses `balance` on the right before any value exists under that name. That is a `NameError`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# First `balance = 1000`, then `balance = balance + 100`, then `balance`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# balance = 1000
# balance = balance + 100
# balance
# ```
#
# `1100`. The original line asks Python to *read* `balance` before it was ever *assigned*. Define first, then update. The runtime only knows what it has been told.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### D2 · Put them in order  ★★☆☆☆
#
# These three lines were run in the order shown and failed, because each name is used before it
# exists:
#
# ```python
# total = price * qty     # ran first
# price = 45.50
# qty = 10
# ```
#
# Rewrite the three lines in an order that runs cleanly from top to bottom and leaves `total` equal
# to **455.0**.

# %%
# the three lines, reordered so each name exists before it is used:
...

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# A name must be assigned *above* the line that uses it. `price` and `qty` have to come before `total`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price = 45.50
# qty = 10
# total = price * qty
# total
# ```
#
# `455.0`. A notebook runs top to bottom, so define the ingredients before you combine them. This is exactly why *Restart & run all* is the real test that a notebook is correct.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you understand that cells share one memory, filled in the order you run them.

# %% [markdown]
# ---

# %% [markdown]
# ## 🧬 E · Types, text & formatting
#
# *Numbers, text, and true/false, plus why mixing them up quietly costs money.*
#
# **Drills:** `type`, `int`/`float`, division, strings, `float()`, f-strings, comparisons.

# %% [markdown]
# ### E1 · Ask for the type  ★☆☆☆☆
#
# For each value below, write a line that prints its **type**. Run it and read the four answers.

# %%
# print the type of each value:
...   # 250
...   # 19.95
...   # "AAPL"
...   # 19.95 > 20

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `type(250)` gives the type; wrap it in `print(...)` to see it. Four lines.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# print(type(250))
# print(type(19.95))
# print(type("AAPL"))
# print(type(19.95 > 20))
# ```
#
# `int`, `float`, `str`, `bool`. A whole number is an `int`, one with a decimal point is a `float`, quoted text is a `str`, and any comparison is a `bool`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E2 · Division makes decimals  ★☆☆☆☆
#
# Write the division of **100** by **4**, store it, and print the value together with its type.
# Notice what kind of number you get back.

# %%
result = ...        # 100 divided by 4
print(result, type(result))

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Just `100 / 4`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# result = 100 / 4
# print(result, type(result))
# ```
#
# `25.0 <class 'float'>`. Division in Python **always** returns a `float`, even when it divides evenly. You get `25.0`, not `25`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E3 · The silent string bug  ★★★☆☆
#
# ⚠️ **Run the cell below.** It does **not** error, yet the answer is nonsense: with `price` still
# text, `price * shares` repeats the text into `"848484"` instead of multiplying. Look at the output,
# then fix it underneath so `cost` is the real number **252.0**.

# %%
price = "84"      # arrived from a file, as text
shares = 3
price * shares

# %% [markdown]
# *Your fix:*

# %%
price = "84"
shares = 3

cost = ...
cost

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `price` is text. Turn it into a number first with `float(...)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `cost = float(price) * shares`
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price = "84"
# shares = 3
#
# cost = float(price) * shares
# cost
# ```
#
# `252.0`. No error is **not** the same as no bug, and this is the dangerous kind: a wrong answer with no complaint. Prices read from files often arrive as text, so convert before you compute.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E4 · Glue text together  ★☆☆☆☆
#
# Given a ticker, use `+` to build the sentence `AAPL is a US stock`. Remember that `+` between
# strings joins them.

# %%
ticker = "AAPL"

sentence = ...
sentence

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `ticker + " is a US stock"`. Mind the leading space inside the quotes.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# ticker = "AAPL"
#
# sentence = ticker + " is a US stock"
# sentence
# ```
#
# `'AAPL is a US stock'`. Between strings, `+` means join, not add. The space had to sit inside the quotes, or you would get `"AAPLis a US stock"`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E5 · Two prices from a file  ★★☆☆☆
#
# Two prices arrived as text: `"52.40"` and `"48.10"`. Add them as real numbers to get their sum.

# %%
p1 = "52.40"
p2 = "48.10"

total = ...
total

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `"52.40" + "48.10"` would glue the text. Convert each with `float(...)` first.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `total = float(p1) + float(p2)`
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# p1 = "52.40"
# p2 = "48.10"
#
# total = float(p1) + float(p2)
# total
# ```
#
# `100.5`. Without `float`, `+` would produce the text `"52.4048.10"`. Converting first is the difference between a sum and a mess.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E6 · Show a tidy price  ★★☆☆☆
#
# An f-string drops values into text, and a `:.2f` inside the braces formats a number to **two
# decimals**. Produce exactly:
#
# `Apple closed at 248.83`

# %%
price = 248.834

message = ...
message

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Put an `f` before the quotes and the variable in braces with its format: `f"Apple closed at {price:.2f}"`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price = 248.834
#
# message = f"Apple closed at {price:.2f}"
# message
# ```
#
# `'Apple closed at 248.83'`. `:.2f` rounds *for display* to two decimals, exactly what prices want. The underlying value is left untouched.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E7 · Show a return as a percent  ★★★☆☆
#
# The other format recipe, `:.2%`, turns a decimal into a percentage. A stock went from **183.56**
# to **248.83**. Compute the simple return and format it:
#
# $$r=\dfrac{p_1-p_0}{p_0}$$
#
# Target output: `Return: 35.56%`

# %%
p0 = 183.56
p1 = 248.83

r = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `r = (p1 - p0) / p0`, the simple-return formula.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `message = f"Return: {r:.2%}"`. The `:.2%` multiplies by 100 and adds the `%` for you.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# p0 = 183.56
# p1 = 248.83
#
# r = (p1 - p0) / p0
# message = f"Return: {r:.2%}"
# message
# ```
#
# `'Return: 35.56%'`. Note that `:.2%` does the ×100 *and* the `%` sign, so never multiply by 100 yourself as well, or you will report 3556%.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E8 · Ask a yes/no question  ★☆☆☆☆
#
# A comparison produces a `bool` (`True` or `False`). Today's close is **251.20**. Write one
# comparison that asks whether it closed **above 250**, and print the answer.

# %%
close = 251.20

beat_250 = ...
print(beat_250)

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Use the `>` operator: `close > 250`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# close = 251.20
#
# beat_250 = close > 250
# print(beat_250)
# ```
#
# `True`. Comparisons (`>`, `<`, `>=`, `<=`, `==`, `!=`) answer yes/no questions. They look modest now, but later they select rows of data, and later still they become the thing a model predicts.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E9 · Convert, compare, report  ★★★★☆
#
# A price arrives as text: `"205.50"`. Without using `if`, build a single line that reports both the
# tidy price and whether it is above 200, exactly like:
#
# `205.50 above 200? True`

# %%
price_text = "205.50"

report = ...
report

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# You will need `float(price_text)` twice: once formatted with `:.2f`, once inside a `> 200` comparison.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `report = f"{float(price_text):.2f} above 200? {float(price_text) > 200}"`
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price_text = "205.50"
#
# report = f"{float(price_text):.2f} above 200? {float(price_text) > 200}"
# report
# ```
#
# `'205.50 above 200? True'`. An f-string can hold *any* expression in its braces: a conversion, a format, even a whole comparison. Four ideas from this section in one line.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### E10 · The f that went missing  ★★☆☆☆
#
# ⚠️ **Run the cell below.** It does not error, and the output is still wrong: it prints the braces
# and the variable name instead of the price.
#
# Find the one character that is missing and fix it.

# %%
close = 248.834

message = "Apple closed at {close:.2f}"
message

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Compare it with E6. What is written immediately before the opening quote there?
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Without the `f`, Python sees an ordinary string and leaves the braces exactly as typed.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# close = 248.834
#
# message = f"Apple closed at {close:.2f}"
# message
# ```
#
# `'Apple closed at 248.83'`. A missing `f` is the quietest bug in this section, because nothing fails: you just publish a report with `{close:.2f}` printed in the middle of it.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you can tell the types apart, convert text to numbers, format for humans, and ask true/false questions.

# %% [markdown]
# ---

# %% [markdown]
# ## 🛠️ F · Functions & methods
#
# *Named tools you call with `(...)`, and methods you call with a dot: `value.method(...)`.*
#
# **Drills:** `round`, `len`, `.upper()`, `.count()`.

# %% [markdown]
# ### F1 · Two little tools  ★☆☆☆☆
#
# Write two lines: one that rounds **19.876** to **2** decimals, and one that reports how many
# characters are in the word `"portfolio"`. Print each.

# %%
# round 19.876 to 2 decimals, and count the letters in "portfolio":
...
...

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `round(x, n)` takes the number and how many decimals; `len(text)` counts characters.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# print(round(19.876, 2))
# print(len("portfolio"))
# ```
#
# `19.88` and `9`. `round` and `len` are two of the small tools you will use in almost every task.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### F2 · Fix the ticker  ★☆☆☆☆
#
# A ticker was typed in lowercase. Use the string method that makes text uppercase to fix it.

# %%
ticker = "jpm"

fixed = ...
fixed

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# A method is called with a dot: `ticker.upper()`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# ticker = "jpm"
#
# fixed = ticker.upper()
# fixed
# ```
#
# `'JPM'`. `.upper()` is a **method**: it belongs to the string and is called with a dot, `value.method()`. That same grammar will run pandas and everything after it.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### F3 · Count occurrences  ★★☆☆☆
#
# `.count(part)` reports how many times a piece of text appears inside a string. Count how many
# times `"a"` appears in `"banana"`.

# %%
word = "banana"

how_many = ...
how_many

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `word.count("a")`, the same dot-grammar as `.upper()`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# word = "banana"
#
# how_many = word.count("a")
# how_many
# ```
#
# `3`. Methods take arguments in their brackets just like functions do. The difference is that they hang off a value with a dot.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### F4 · Assemble a headline  ★★★☆☆
#
# Combine a method and a format recipe. Given a lowercase ticker and a price, build:
#
# `JPM closed at 231.45`

# %%
ticker = "jpm"
price = 231.451

headline = ...
headline

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# A method call is fine *inside* an f-string: `f"{ticker.upper()} closed at {price:.2f}"`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# ticker = "jpm"
# price = 231.451
#
# headline = f"{ticker.upper()} closed at {price:.2f}"
# headline
# ```
#
# `'JPM closed at 231.45'`. Braces in an f-string happily hold a method call and a format spec at once.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### F5 · How much of the name?  ★★★☆☆
#
# For `name = "Coca-Cola Company"`, compute the fraction of its characters that are a lowercase
# `"o"`, and show it as a percentage (for example `17.65%`). You will need a method *and* a
# function.

# %%
name = "Coca-Cola Company"

fraction_o = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Count the `"o"`s with `name.count("o")` and the total characters with `len(name)`, then divide.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `fraction_o = name.count("o") / len(name)`, then `f"{fraction_o:.2%}"`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# name = "Coca-Cola Company"
#
# fraction_o = name.count("o") / len(name)
# message = f"{fraction_o:.2%}"
# message
# ```
#
# `'17.65%'`, that is 3 of the 17 characters. A method and a function, combined and formatted: the shape of most real code.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you can call functions and methods, and you recognise the `value.method(...)` pattern everywhere.

# %% [markdown]
# ---

# %% [markdown]
# ## 📊 G · Lists
#
# *Many values, in order, under one name. Lists are the structure you will use most this week.*
#
# **Drills:** create, `len`, indexing, negative indexing, slicing, `.append`, `.index`, `min`/`max`/`sum`.

# %% [markdown]
# ### G1 · Collect a week  ★☆☆☆☆
#
# Put these five closing prices into a list called `closes`, in order:
# **183.56, 182.19, 179.87, 179.15, 183.48**. Then report how many values it holds.

# %%
closes = ...
count = ...
print(count)

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# A list is written with square brackets and commas: `[183.56, 182.19, ...]`. `len(closes)` counts the items.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [183.56, 182.19, 179.87, 179.15, 183.48]
# count = len(closes)
# print(count)
# ```
#
# `5`. One name now holds the whole week. A real year is about 252 of these, far too many for one variable each.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G2 · Pick out three days  ★☆☆☆☆
#
# From the list below, pull the **first** day, the **third** day, and the **last** day into three
# variables. Remember that positions count from **0**, and `-1` is the last.

# %%
closes = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]

first = ...
third = ...
last  = ...
print(first, third, last)

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# First is `closes[0]`, third is `closes[2]` (not `[3]`), last is `closes[-1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
#
# first = closes[0]
# third = closes[2]
# last  = closes[-1]
# print(first, third, last)
# ```
#
# `61.2 60.9 63.75`. The index is the *distance from the start*, so the third item sits at position 2. `[-1]` is useful: it gives the latest value, whatever the length.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G3 · Yesterday vs today  ★★☆☆☆
#
# Using **negative** indexing only, compute how much the **last** price changed from the
# **second-to-last** (the last minus the one before it).

# %%
closes = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]

change = ...
change

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# The last is `closes[-1]`; the one before it is `closes[-2]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
#
# change = closes[-1] - closes[-2]
# change
# ```
#
# `-0.25`, so the price slipped on the final day. Negative indices count from the end, so `[-2]` is always the second-last value without your knowing the length.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G4 · Off the end  ★★☆☆☆
#
# ⚠️ **Run the cell below.** It asks for a seventh price from a six-item list and fails. Read the
# error, then fix it underneath so `sixth` holds the **sixth (last)** price.

# %%
prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
prices[6]

# %% [markdown]
# *Your fix:*

# %%
prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]

sixth = ...
sixth

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Six items fill positions **0 to 5**. Position 6 does not exist, which is the `IndexError`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The sixth item is `prices[5]`, or equivalently `prices[-1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
#
# sixth = prices[5]
# sixth
# ```
#
# `63.75`. The count is 6, but the positions are 0 to 5, the classic *off-by-one*. `prices[-1]` sidesteps it entirely.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G5 · A window in the middle  ★★☆☆☆
#
# A **slice** `list[start:stop]` takes from `start` up to, but **not including**, `stop`. From the
# ten-day list, extract the four days at positions **3, 4, 5, 6**.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]

window = ...
window

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# To include position 6, the `stop` must be 7 (one past the last one you want): `closes[3:7]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
#
# window = closes[3:7]
# window
# ```
#
# `[73.1, 74.4, 73.9, 75.2]`. The item count equals `stop - start`, here `7 - 3 = 4`. The excluded `stop` feels odd at first, then becomes second nature.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G6 · Both ends  ★★☆☆☆
#
# Leave a slice's start or stop blank to mean *from the beginning* or *to the end*. From the same
# list, take the **first three** days and, separately, the **last three** days.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]

first_three = ...
last_three  = ...
print(first_three)
print(last_three)

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `closes[:3]` starts from the beginning; `closes[-3:]` runs to the end.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
#
# first_three = closes[:3]
# last_three  = closes[-3:]
# print(first_three)
# print(last_three)
# ```
#
# `[71.2, 72.0, 70.5]` and `[74.8, 76.0, 75.5]`. An empty side just means all the way in that direction.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G7 · A new close arrives  ★☆☆☆☆
#
# Markets closed and a new price of **77.10** came in. Use `.append(...)` to add it to the end of the
# list, then report the new length.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4]

...
print(len(closes))

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# `closes.append(77.10)` adds to the end, then `len(closes)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4]
#
# closes.append(77.10)
# print(len(closes))
# ```
#
# `6`. `.append` changes the list in place, so notice there is no `closes = ...`. The list itself grows by one.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G8 · Where is the low?  ★★★☆☆
#
# `.index(value)` reports the **position** of a value in a list. Find the lowest price with
# `min(...)`, then use `.index(...)` to find *which day* (position) it fell on.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]

lowest = ...
low_position = ...
print(lowest, low_position)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `min(closes)` gives the lowest value.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Feed that straight in: `closes.index(min(closes))`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
#
# lowest = min(closes)
# low_position = closes.index(lowest)
# print(lowest, low_position)
# ```
#
# `70.5 2`, so the low was at position 2. Pairing `min` with `.index`, that is *what* was the extreme and *where*, is a move you will make constantly.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G9 · Summarise the week  ★★☆☆☆
#
# From one list, report three summaries: the **highest** price, the **lowest** price, and the
# **average**. The average is the sum divided by the count:
#
# $$\bar{p}=\dfrac{\text{sum of prices}}{\text{how many prices}}$$

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]

highest = ...
lowest  = ...
average = ...
print(highest, lowest, average)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `max(closes)` and `min(closes)` give the extremes.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `average = sum(closes) / len(closes)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
#
# highest = max(closes)
# lowest  = min(closes)
# average = sum(closes) / len(closes)
# print(highest, lowest, average)
# ```
#
# `76.0 70.5 73.66` (wrap the average in `round(..., 2)` to tidy it). `sum`/`len` is your first statistic built from raw parts, exactly what a data table will compute for you in one step later in the course.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G10 · How wide did it swing?  ★★★☆☆
#
# A stock's range relative to its floor is a rough gauge of how much it moved. Compute the range as
# a **percentage of the lowest** price:
#
# $$\text{relative range}=\dfrac{\max-\min}{\min}$$
#
# and format it as a percent.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]

relative_range = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# First the range: `max(closes) - min(closes)`. Then divide by `min(closes)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `relative_range = (max(closes) - min(closes)) / min(closes)`, then `f"{relative_range:.2%}"`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
#
# relative_range = (max(closes) - min(closes)) / min(closes)
# message = f"{relative_range:.2%}"
# message
# ```
#
# `'7.80%'`. Three tools, `max`, `min`, and a format recipe, combined into a genuine if crude risk measure.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### G11 · From an empty cell  ★★★☆☆
#
# No scaffolding this time. Write the whole thing yourself, from the empty cell.
#
# Starting from the five closes **71.2, 72.0, 70.5, 73.1, 74.4**:
#
# 1. put them in a list called `closes`
# 2. a sixth day closes at **77.10**, so add it
# 3. the first day turns out to belong to the previous week, so drop it with a slice
# 4. report how many days are left, and what the new first day is

# %%
...

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Four lines, one per step. `closes = [...]`, then `.append(...)`, then `closes = closes[1:]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The last step is a single `print` with two values in it: `len(closes)` and `closes[0]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4]
# closes.append(77.10)
# closes = closes[1:]
# print(len(closes), closes[0])
# ```
#
# `5 72.0`. Nothing here is new, and that is the point: with no blanks to fill in you have to remember the order the pieces go in, which is what the exam actually asks of you.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you can build a list, reach any day or window, grow it, locate values, and summarise it.

# %% [markdown]
# ---

# %% [markdown]
# ## 🐞 H · Reading errors
#
# *An error message is a diagnosis, not a scolding. Each of these cells breaks on purpose so you can meet the four errors of week one and repair them.*
#
# **Drills:** `NameError`, `TypeError`, `SyntaxError`, `IndexError`.

# %% [markdown]
# ### H1 · A capital mistake  ★★☆☆☆
#
# ⚠️ **Run the cell below.** It fails with a **NameError**. Look closely at the capital letters: the
# value was stored as `Revenue`, but the last line asks for `revenue`, and Python treats those as two
# different names. Read the message, then fix it underneath.

# %%
Revenue = 5000
costs = 3200
revenue - costs

# %% [markdown]
# *Your fix:*

# %%
Revenue = 5000
costs = 3200

profit = ...
profit

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `Revenue` and `revenue` are different names. Only one of them holds 5000.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Match the capital: `profit = Revenue - costs`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# Revenue = 5000
# costs = 3200
#
# profit = Revenue - costs
# profit
# ```
#
# `1800`. A `NameError` almost always means a typo, a wrong capital letter, or a cell you forgot to run. Check the exact spelling first.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H2 · Wrong kind of thing  ★★☆☆☆
#
# ⚠️ **Run the cell below.** It fails with a **TypeError**, because you cannot add a number to text.
# Read the message, then fix it underneath so `final` is the price plus the markup, as a number.

# %%
price_text = "230.10"     # text, from a file
markup = 5
price_text + markup

# %% [markdown]
# *Your fix:*

# %%
price_text = "230.10"
markup = 5

final = ...
final

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# A `TypeError` means an operation met the wrong type. Convert the text to a number first.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `final = float(price_text) + markup`
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# price_text = "230.10"
# markup = 5
#
# final = float(price_text) + markup
# final
# ```
#
# `235.1`. A `TypeError` is Python refusing to guess what you meant between mismatched types, usually the sign that a number is secretly text.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H3 · Python cannot even start  ★☆☆☆☆
#
# ⚠️ **Run the cell below.** It fails with a **SyntaxError**, before it runs at all, because a bracket
# is missing. Read the message, then write the corrected line underneath so it prints `Total: 500`.

# %%
total = 500
print("Total:", total

# %% [markdown]
# *Your fix:*

# %%
total = 500

# write the corrected print statement:
...

# %% [markdown]
# <details>
# <summary>💡 Hint</summary>
#
# Count the brackets in the broken line: one `(` opens, but nothing closes it.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# total = 500
#
# print("Total:", total)
# ```
#
# `Total: 500`. A `SyntaxError` is about *shape*, not meaning: a missing bracket, quote, or comma. Python cannot even begin until the line is well-formed.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### H4 · One step too far  ★★☆☆☆
#
# ⚠️ **Run the cell below.** It fails with an **IndexError**: with four prices, the positions are 0 to
# 3, so `prices[days]` (position 4) runs off the end. Read the message, then fix it underneath so
# `last` holds the actual final price.

# %%
prices = [61.20, 62.05, 60.90, 63.10]
days = len(prices)
prices[days]

# %% [markdown]
# *Your fix:*

# %%
prices = [61.20, 62.05, 60.90, 63.10]

last = ...
last

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Four items sit at positions 0, 1, 2, 3. The length is 4, but there is no position 4.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Use `prices[3]`, or the length-proof `prices[-1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# prices = [61.20, 62.05, 60.90, 63.10]
#
# last = prices[-1]
# last
# ```
#
# `63.1`. An `IndexError` means you reached past the end of the list, nearly always an off-by-one. Using `len(prices)` as an index is the classic version of the mistake, since a length of 4 points one step beyond the last item. `[-1]` is the safe way to say the last one.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# > ✅ **Checkpoint** · you can recognise and repair all four of week one's errors from their messages.

# %% [markdown]
# ---

# %% [markdown]
# ## 📈 I · Putting it together, the analyst's toolkit
#
# *Everything from today, aimed at real prices. This is the exact work the case will ask of you.*
#
# **Drills:** simple returns, parallel lists, locating extremes, weighting, compounding, a formatted report.

# %% [markdown]
# ### I1 · One day's return  ★★☆☆☆
#
# Yesterday a stock closed at **183.56**, today at **182.19**. Compute the simple return and show it
# as a percentage:
#
# $$r=\dfrac{p_1-p_0}{p_0}$$

# %%
p0 = 183.56
p1 = 182.19

r = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `r = (p1 - p0) / p0`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `message = f"Return: {r:.2%}"`
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# p0 = 183.56
# p1 = 182.19
#
# r = (p1 - p0) / p0
# message = f"Return: {r:.2%}"
# message
# ```
#
# `'Return: -0.75%'`, a small down day. The percentage change in price is the basic quantity used throughout the course.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I2 · A whole window's return, twice  ★★★★☆
#
# There are two ways to measure what a window did, and a good analyst checks one against the other.
#
# **Route A:** compare the two ends directly, $\dfrac{p_{\text{last}}-p_{\text{first}}}{p_{\text{first}}}$.
#
# **Route B:** take the first three days only, and compound their two daily returns:
# $(1+r_1)(1+r_2)-1$.
#
# Compute both over the **first three closes**, and print whether they agree.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4]
first_three = closes[:3]

route_a = ...
r1 = ...
r2 = ...
route_b = ...

print("A:", route_a)
print("B:", route_b)
print("agree:", ...)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Route A uses `first_three[0]` and `first_three[-1]`. Route B needs the two daily returns first.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The two answers are floats, so compare them rounded: `round(route_a, 10) == round(route_b, 10)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4]
# first_three = closes[:3]
#
# route_a = (first_three[-1] - first_three[0]) / first_three[0]
# r1 = (first_three[1] - first_three[0]) / first_three[0]
# r2 = (first_three[2] - first_three[1]) / first_three[1]
# route_b = (1 + r1) * (1 + r2) - 1
#
# print("A:", route_a)
# print("B:", route_b)
# print("agree:", round(route_a, 10) == round(route_b, 10))
# ```
#
# Both give **-0.98%**, and they agree. That is not a coincidence: compounding the daily steps *is* the end-to-end return, which is why you may never add returns together. Note the rounding in the comparison. Two floats that are mathematically equal can still differ in the last bits, so `==` on raw floats is a trap.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I3 · Which day was best?  ★★★☆☆
#
# Two lists run in parallel, a date and a price at each position. Find the **highest** close and,
# using `.index`, the **date** it happened on.

# %%
dates  = ["Jan 02", "Jan 03", "Jan 04", "Jan 05", "Jan 08"]
closes = [183.56, 182.19, 179.87, 179.15, 183.48]

best_price = ...
best_date  = ...
print(best_date, best_price)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# `max(closes)` is the highest price.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# Find its position and read the *same* position in `dates`: `dates[closes.index(max(closes))]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# dates  = ["Jan 02", "Jan 03", "Jan 04", "Jan 05", "Jan 08"]
# closes = [183.56, 182.19, 179.87, 179.15, 183.48]
#
# best_price = max(closes)
# best_date  = dates[closes.index(best_price)]
# print(best_date, best_price)
# ```
#
# `Jan 02 183.56`. Two lists kept *in step*, connected only by position: `.index` finds *where* in one, and you read the same spot in the other. Next week a table keeps them together so they can never drift apart.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I4 · The worst day  ★★★★☆
#
# From the week below, find the **worst single-day return** and the **date** it fell on. Five prices
# give **four** daily returns. Build them by hand into a list, then locate the minimum.
#
# Watch the offset: the return in position `k` of your list happened on day `dates[k+1]`, because a
# return needs the *previous* day too.

# %%
dates  = ["Jan 02", "Jan 03", "Jan 04", "Jan 05", "Jan 08"]
closes = [183.56, 182.19, 179.87, 179.15, 183.48]

r1 = (closes[1] - closes[0]) / closes[0]
r2 = ...
r3 = ...
r4 = ...
returns = [r1, r2, r3, r4]

worst = ...
worst_date = ...
print(worst_date, worst)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Each return follows the same shape as `r1`, shifted along one: `r2` uses `closes[2]` and `closes[1]`, and so on.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `worst = min(returns)`; its position is `returns.index(worst)`; the date is `dates[returns.index(worst) + 1]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# dates  = ["Jan 02", "Jan 03", "Jan 04", "Jan 05", "Jan 08"]
# closes = [183.56, 182.19, 179.87, 179.15, 183.48]
#
# r1 = (closes[1] - closes[0]) / closes[0]
# r2 = (closes[2] - closes[1]) / closes[1]
# r3 = (closes[3] - closes[2]) / closes[2]
# r4 = (closes[4] - closes[3]) / closes[3]
# returns = [r1, r2, r3, r4]
#
# worst = min(returns)
# worst_date = dates[returns.index(worst) + 1]
# print(worst_date, f"{worst:.2%}")
# ```
#
# `Jan 04 -1.27%`. The `+1` is the whole puzzle: a list of 4 returns lines up against days 2 to 5, not 1 to 5. Doing this by hand for four returns is exactly why loops (the next module) exist.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I5 · Recover yesterday's price, and prove it  ★★★★☆
#
# A stock closed today at **185.00**, up **2.5%** on the day. What was *yesterday's* close? The return
# formula rearranged gives:
#
# $$p_0=\dfrac{p_1}{1+r}$$
#
# Compute it, then **check your own answer**: put your `p0` back into the ordinary return formula and
# confirm you get 2.5% out again.

# %%
p1 = 185.00
r = 0.025

p0 = ...
check = ...

print("yesterday :", p0)
print("recomputed:", check)
print("matches   :", ...)

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Read the formula across: divide today's price by `(1 + r)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The check runs the normal formula forwards: `(p1 - p0) / p0`. Compare it to `r` with `round(..., 10)` on both sides, because these are floats.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# p1 = 185.00
# r = 0.025
#
# p0 = p1 / (1 + r)
# check = (p1 - p0) / p0
#
# print("yesterday :", p0)
# print("recomputed:", check)
# print("matches   :", round(check, 10) == round(r, 10))
# ```
#
# `180.49`, and the check returns 2.5% exactly. Today's price is yesterday's grown by `(1 + r)`, so dividing it back out recovers where you started.
#
# The habit matters more than the answer: when you rearrange a formula, run it forwards again. It costs one line and it catches an inverted sign every time.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I6 · A weighted portfolio return  ★★★☆☆
#
# A portfolio holds three stocks with **weights** 0.5, 0.3, 0.2 (they sum to 1) and daily returns
# 0.04, -0.01, 0.02. The portfolio return is each weight times its return, all added up:
#
# $$r_p = w_1 r_1 + w_2 r_2 + w_3 r_3$$
#
# Compute it and show it as a percentage.

# %%
w1, w2, w3 = 0.5, 0.3, 0.2
r1, r2, r3 = 0.04, -0.01, 0.02

portfolio_return = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Multiply each weight by its own return, then add the three products.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `portfolio_return = w1*r1 + w2*r2 + w3*r3`, then format with `:.2%`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# w1, w2, w3 = 0.5, 0.3, 0.2
# r1, r2, r3 = 0.04, -0.01, 0.02
#
# portfolio_return = w1*r1 + w2*r2 + w3*r3
# message = f"Portfolio: {portfolio_return:.2%}"
# message
# ```
#
# `'Portfolio: 2.10%'`. A weighted average is how every real portfolio return is built. The weights sum to 1, so the result always sits among the individual returns.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I7 · The middle price, no sorting  ★★★★★
#
# Three desks quote **182.19**, **179.87**, and **183.48**. Find the **median** (the middle value)
# **without** sorting them and without `if`.
#
# Think about what is left over: if you take the running total of all three and remove the largest and
# the smallest, what single value remains?

# %%
a = 182.19
b = 179.87
c = 183.48

median = ...
median

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# The three values add up to a fixed total. The median is that total with the biggest and the smallest taken away.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `median = a + b + c - max(a, b, c) - min(a, b, c)`. Note `max` and `min` accept several arguments, not only a list.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# a = 182.19
# b = 179.87
# c = 183.48
#
# median = a + b + c - max(a, b, c) - min(a, b, c)
# median
# ```
#
# `182.18999999999994`, which is 182.19 (the trailing digits are floating-point dust, and `round(median, 2)` tidies them away). Nothing new was needed, only a fresh way to combine `sum`-style addition with `max` and `min`. That reframing, the middle is what remains once the extremes are removed, is the kind of step the harder exercises look for.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I8 · Compounding beats adding  ★★★☆☆
#
# Four daily returns are given. The true return over all four days is **not** their sum: each day
# compounds on the last, so you multiply the growth factors and subtract 1:
#
# $$r_\text{total} = (1+r_1)(1+r_2)(1+r_3)(1+r_4) - 1$$
#
# Compute the compounded return and format it as a percentage.

# %%
r = [0.012, -0.004, 0.008, -0.011]

compounded = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Each factor is `1 + r[k]`. Multiply all four together, then subtract 1.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# `compounded = (1 + r[0]) * (1 + r[1]) * (1 + r[2]) * (1 + r[3]) - 1`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# r = [0.012, -0.004, 0.008, -0.011]
#
# compounded = (1 + r[0]) * (1 + r[1]) * (1 + r[2]) * (1 + r[3]) - 1
# message = f"Compounded: {compounded:.2%}"
# message
# ```
#
# `'Compounded: 0.48%'`, against a naive sum of `0.50%`. Close over a few small days, but the gap grows fast, which is why returns are compounded, not added.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### I9 · The one-line risk report  ★★★★☆
#
# The capstone. From one week of closes, build a **single** formatted line reporting the week's return
# (as a percent), the average price (2 decimals), and the highest and lowest prices. Aim for something
# like:
#
# `Week 3.68% | avg 74.10 | high 76.00 | low 70.50`

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]

week_return = ...
average = ...
report = ...
report

# %% [markdown]
# <details>
# <summary>💡 Hint 1</summary>
#
# Build the pieces first: `week_return` (first vs last), `average` (`sum`/`len`), and use `max`/`min` directly in the f-string.
#
# </details>

# %% [markdown]
# <details>
# <summary>💡 Hint 2</summary>
#
# The f-string can hold it all: `f"Week {week_return:.2%} | avg {average:.2f} | high {max(closes):.2f} | low {min(closes):.2f}"`.
#
# </details>

# %% [markdown]
# <details>
# <summary>✅ Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
#
# week_return = (closes[-1] - closes[0]) / closes[0]
# average = sum(closes) / len(closes)
# report = f"Week {week_return:.2%} | avg {average:.2f} | high {max(closes):.2f} | low {min(closes):.2f}"
# report
# ```
#
# `'Week 6.04% | avg 73.66 | high 76.00 | low 70.50'`. Returns, an average, extremes, formatting: every idea from today working together. This is the kind of summary an analyst produces.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## 🏁 Done
#
# That covers all of Session 1: running and formatting output, arithmetic with powers and percentages, variables, types, functions and methods, and lists, ending with a few realistic tasks such as a weighted return and a one-line risk report.
#
# **Next:** open `session_01_case.ipynb` (*The Analyst's Notebook, Part 1*) and apply these tools to a full year of real Apple and Coca-Cola prices.
#
# *Stuck for more than 15 minutes on anything? Ask a friend, ask an AI for a hint (not the answer), or email me at `jobo@econ.au.dk`.*
