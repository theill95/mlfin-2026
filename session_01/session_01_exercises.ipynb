# %% [markdown]
# # Session 1 — Exercises
#
# 24 exercises, grouped to match the lecture. Work top to bottom.
#
# **How to use this notebook**
#
# - Every exercise has a task, then a code cell for your work. Cells with `...`
#   are placeholders — replace them with real code. Cells without `...` are
#   already complete: read them, predict what they do, then run them to check.
# - Click **Hint** only after you have genuinely tried. Click **Solution** to
#   check your work, not to skip it.
# - Run cells top to bottom. The notebook runs cleanly from a fresh kernel even
#   before you fill anything in — the placeholders are valid (if unhelpful)
#   Python, so nothing crashes while you work.
# - Nothing here needs a file or the internet. Every exercise is self-contained.

# %% [markdown]
# ## A · Notebooks and runtime state

# %% [markdown]
# ### Exercise A1 — Trace two cells
#
# Two cells were run in the order shown (Cell 1 first, then Cell 2). Before
# running anything, write down what `total` equals after both have run.
#
# ```python
# # Cell 1
# total = 500
# ```
#
# ```python
# # Cell 2
# total = total + 250
# ```

# %%
total = 500
total = total + 250
total

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Read the second line from the right: take the current value of `total`, add 250, store the result back into `total`. The old value is gone.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# total = 500
# total = total + 250
# total
# ```
#
# **750.** Assignment overwrites — `total` is reassigned to its old value plus 250.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise A2 — Diagnose a fresh-runtime error
#
# A student opens a fresh notebook and runs **only** the cell below — nothing
# else has been run first:
#
# ```python
# balance = balance + 100
# ```
#
# This raises an error.
#
# 1. Name the error type.
# 2. Explain, in one sentence, why it happens.
#
# Then, in the work cell, write it correctly: first give `balance` a starting
# value of 1000, then keep the update `balance = balance + 100`, then show the
# result.

# %%
...

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The error is a **NameError** — Python cannot add 100 to a name that has never been assigned anything.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# Two lines are needed: `balance = 1000` first, then `balance = balance + 100`, then `balance` on its own line to display it.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# balance = 1000
# balance = balance + 100
# balance
# ```
#
# **1100.** The original cell fails because its very first use of `balance` is on the right-hand side of an update — Python needs a value stored under that name before it can add to it.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## B · Expressions, variables, types

# %% [markdown]
# ### Exercise B1 — Recognise the types
#
# Without running anything, write down the type of each of these five values:
# `42`, `4.2`, `"42"`, `42 > 4`, `"4" + "2"`. Then run the cell to check.

# %%
print(type(42))
print(type(4.2))
print(type("42"))
print(type(42 > 4))
print(type("4" + "2"))

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# A number with a decimal point is `float`; a whole number without one is `int`; anything in quotes is `str`, no matter what it looks like; a comparison always gives `bool`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# print(type(42))        # int
# print(type(4.2))       # float
# print(type("42"))      # str
# print(type(42 > 4))    # bool
# print(type("4" + "2")) # str
# ```
#
# **int, float, str, bool, str.** `"4" + "2"` glues text together into the *text* `"42"` — it never becomes the number 42.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise B2 — Predict an arithmetic expression
#
# Predict the value of each expression below, then run the cell to check.

# %%
print(2 + 3 * 4)
print((2 + 3) * 4)

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Python follows the usual order of operations: multiplication happens before addition, unless parentheses say otherwise.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# print(2 + 3 * 4)    # 14
# print((2 + 3) * 4)  # 20
# ```
#
# **14 and 20.** Same numbers, different grouping, different answer.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise B3 — Complete the growth formula
#
# An investment of 2,000 grows at 6% per year. Complete the expression to
# compute its value after 8 years.

# %%
principal = 2000
rate = 0.06
years = 8

future_value = ...
future_value

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Recall `1000 * (1 + 0.04) ** 5` from the lecture — same shape, different numbers.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# `future_value = principal * (1 + rate) ** years`
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# principal = 2000
# rate = 0.06
# years = 8
#
# future_value = principal * (1 + rate) ** years
# future_value
# ```
#
# **3187.696...** — Python prints the full float; round it with `round(future_value, 2)` if you want 3187.70.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise B4 — Modify the worked example
#
# Reuse the same compound-growth formula, but now for an investment of 5,000 at
# a rate of 3.5% over 12 years. Complete the formula line.

# %%
principal = 5000
rate = 0.035
years = 12

future_value = ...
future_value

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Same formula as B3, just applied to the new numbers already given above.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# principal = 5000
# rate = 0.035
# years = 12
#
# future_value = principal * (1 + rate) ** years
# future_value
# ```
#
# **7555.343...** The formula never changes — only the inputs do. That reuse is the entire idea of a variable.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise B5 — Diagnose a silent wrong answer
#
# This cell runs without any error — and gives a wrong-looking answer:
#
# ```python
# price = "84"
# shares = 3
# cost = price * shares
# ```
#
# What does `cost` actually equal, and why does Python not complain? Then, in
# the work cell, write a corrected version that computes the real total cost
# as a number.

# %%
price = "84"
shares = 3

cost = ...
cost

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# `price * shares` with `price` still text does not multiply arithmetically — Python repeats the text `shares` times instead.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# Convert first: `float(price) * shares`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# price = "84"
# shares = 3
#
# cost = float(price) * shares
# cost
# ```
#
# **252.0.** The original code computes `"84" * 3`, which is the text `"848484"` — three copies of the string, not a price times a quantity.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise B6 — Build a position report
#
# You hold 250 shares bought at 36.80 each. The price is now 42.15. Using an
# f-string, build a message in exactly this form (numbers will differ if you
# change the inputs above): `"Position value: 10537.50, gain: 14.54%"`

# %%
shares = 250
buy_price = 36.80
current_price = 42.15

position_value = ...
gain = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# `position_value` uses `current_price` and `shares`; `gain` is the simple-return formula applied to the two prices.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# message = f"Position value: {position_value:.2f}, gain: {gain:.2%}"
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# shares = 250
# buy_price = 36.80
# current_price = 42.15
#
# position_value = current_price * shares
# gain = (current_price - buy_price) / buy_price
# message = f"Position value: {position_value:.2f}, gain: {gain:.2%}"
# message
# ```
#
# **"Position value: 10537.50, gain: 14.54%"** — the same two format recipes from the lecture, `:.2f` and `:.2%`, used together.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## C · Functions and methods

# %% [markdown]
# ### Exercise C1 — Predict four built-ins
#
# Predict the result of each line, then run the cell to check.

# %%
print(round(19.876, 1))
print(len("portfolio"))
print(max(3, 9, 5))
print(sorted([40, 10, 25]))

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# `round` keeps the stated number of decimals; `len` counts characters; `max` and `sorted` behave exactly as they do on paper.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# print(round(19.876, 1))       # 19.9
# print(len("portfolio"))       # 9
# print(max(3, 9, 5))           # 9
# print(sorted([40, 10, 25]))   # [10, 25, 40]
# ```
#
# **19.9, 9, 9, [10, 25, 40].** Four small tools you will use constantly.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise C2 — Trace print versus a bare expression
#
# Without running it, say how many lines of output this cell produces, and
# what they are. Then run it to check.

# %%
a = 10
a + 5
print(a)
a * 2

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Only `print(...)` displays output in the middle of a cell. A bare expression only displays automatically if it is the very **last** line of the cell — and here, `a * 2` is last but its value is still computed silently unless you look for it.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# a = 10
# a + 5      # computed, not shown: not printed, not last line
# print(a)   # shown: 10
# a * 2      # this IS the last line, so it also displays: 20
# ```
#
# **Two lines of output: `10` then `20`.** `a + 5` is thrown away — not printed and not last. `print(a)` shows explicitly. `a * 2`, being the cell's last line, displays automatically even without `print`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise C3 — Complete a method call
#
# A ticker was typed in lowercase by mistake. Complete the line to fix it.

# %%
ticker = "jpm"
ticker_fixed = ...
ticker_fixed

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# A string method from the lecture turns lowercase into uppercase.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# ticker = "jpm"
# ticker_fixed = ticker.upper()
# ticker_fixed
# ```
#
# **"JPM".** `.upper()` is a method: it belongs to the string and is called with a dot.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise C4 — Combine a method with a format recipe
#
# Given a lowercase ticker and a price, build the message
# `"JPM closed at 231.45"` using `.upper()` and an f-string.

# %%
ticker = "jpm"
price = 231.45

message = ...
message

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# f"{ticker.upper()} closed at {price:.2f}"
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# ticker = "jpm"
# price = 231.45
#
# message = f"{ticker.upper()} closed at {price:.2f}"
# message
# ```
#
# **"JPM closed at 231.45".** A method call sits happily inside an f-string's braces, exactly like a variable.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## D · Lists

# %% [markdown]
# ### Exercise D1 — Predict three indices
#
# Predict `prices[0]`, `prices[2]`, and `prices[-1]` for the list below, then
# run the cell to check.

# %%
prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
print(prices[0])
print(prices[2])
print(prices[-1])

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Counting starts at 0. `-1` always means the last item, whatever the list's length.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
# print(prices[0])   # 61.2
# print(prices[2])   # 60.9
# print(prices[-1])  # 63.75
# ```
#
# **61.2, 60.9, 63.75.** Position 0 is the first price, position 2 is the third, and -1 is the last regardless of length.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise D2 — Connect negative and positive indices
#
# For the same six-price list, confirm that `prices[-1]` is the same item as
# `prices[5]`, and that `prices[-3]` is the same item as `prices[3]`. Use
# `len()` to check the list's length first.

# %%
prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
print(len(prices))
print(prices[-1] == prices[5])
print(prices[-3] == prices[3])

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Negative index `-k` always corresponds to positive index `len(list) - k`. With 6 items, `-1` is position `6 - 1 = 5`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
# print(len(prices))          # 6
# print(prices[-1] == prices[5])  # True
# print(prices[-3] == prices[3])  # True
# ```
#
# **6, True, True.** Negative indices are just a shortcut for counting from the end instead of the start.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise D3 — Diagnose an IndexError
#
# This raises an error:
#
# ```python
# prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
# sixth_price = prices[6]
# ```
#
# Name the error type, explain why it happens, then write a corrected line
# that correctly retrieves the sixth (i.e. last) price.

# %%
prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
sixth_price = ...
sixth_price

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# There are 6 items, so valid positions are 0 through 5 — index 6 asks for a 7th item that does not exist: **IndexError**.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# The sixth price sits at index 5, or equivalently -1.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# prices = [61.20, 62.05, 60.90, 63.10, 64.00, 63.75]
# sixth_price = prices[5]
# sixth_price
# ```
#
# **63.75.** `prices[-1]` would give the identical answer.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise D4 — Complete a slice
#
# From the 10-day list below, extract just the middle four days — positions 3,
# 4, 5, 6.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
middle_four = ...
middle_four

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Positions 3, 4, 5, 6 → `start=3`, `stop=7` (the stop position is excluded, so it must be one past the last position you want).
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# `closes[3:7]`
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
# middle_four = closes[3:7]
# middle_four
# ```
#
# **[73.1, 74.4, 73.9, 75.2].** Four items: `7 - 3 = 4`.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise D5 — Two ways to slice the end
#
# Using the same list, get the **last three** days two different ways: once
# with an open-ended slice starting at a positive position, once by counting
# from the end with a negative start. Confirm both give the same answer.

# %%
closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
last_three_a = ...
last_three_b = ...
print(last_three_a)
print(last_three_b)
print(last_three_a == last_three_b)

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# There are 10 items, so the last three start at position 7: `closes[7:]`. Counting from the end, that is `closes[-3:]`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# closes = [71.2, 72.0, 70.5, 73.1, 74.4, 73.9, 75.2, 74.8, 76.0, 75.5]
# last_three_a = closes[7:]
# last_three_b = closes[-3:]
# print(last_three_a)
# print(last_three_b)
# print(last_three_a == last_three_b)
# ```
#
# **[74.8, 76.0, 75.5] both times, and True.** Leaving the stop position empty means "to the end of the list".
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise D6 — Compute a range over part of a list
#
# Two tickers' eight-day closes are given below. Using only the **first four**
# days of `stock_b`, compute its price range (highest minus lowest).

# %%
stock_a = [140.2, 141.5, 139.8, 142.0, 143.1, 141.9, 144.0, 145.2]
stock_b = [88.4, 87.9, 89.1, 90.0, 91.2, 90.5, 89.8, 91.0]

first_four_b = ...
range_b = ...
range_b

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Slice the first four positions of `stock_b`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# The range of a list is `max(...) - min(...)`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# stock_a = [140.2, 141.5, 139.8, 142.0, 143.1, 141.9, 144.0, 145.2]
# stock_b = [88.4, 87.9, 89.1, 90.0, 91.2, 90.5, 89.8, 91.0]
#
# first_four_b = stock_b[:4]
# range_b = max(first_four_b) - min(first_four_b)
# range_b
# ```
#
# **2.1** (90.0 − 87.9) — though Python will actually display `2.0999999999999943`. That is not a mistake: computers store decimal numbers like 90.0 and 87.9 in binary, which cannot represent most decimals exactly, so tiny rounding dust appears after subtraction. `round(range_b, 2)` cleans it up for display. `stock_a` is not needed here — it is used in the next exercise.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise D7 — Compute and format a period return
#
# For `stock_a` above, compute the return from day 1 to day 5 (index 0 to
# index 4), then print it as a percentage using the message pattern from
# Section B.

# %%
stock_a = [140.2, 141.5, 139.8, 142.0, 143.1, 141.9, 144.0, 145.2]

start = ...
end = ...
period_return = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# `start` is `stock_a[0]`, `end` is `stock_a[4]` — the same simple-return formula from the lecture applies to any two prices.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# message = f"Period return: {period_return:.2%}"
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# stock_a = [140.2, 141.5, 139.8, 142.0, 143.1, 141.9, 144.0, 145.2]
#
# start = stock_a[0]
# end = stock_a[4]
# period_return = (end - start) / start
# message = f"Period return: {period_return:.2%}"
# message
# ```
#
# **"Period return: 2.07%".** Indexing picks the two prices; the same return formula from Section 7 of the lecture does the rest.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## E · Reading errors

# %% [markdown]
# ### Exercise E1 — Name three error types
#
# For each snippet below, name the error it produces: `NameError`, `TypeError`,
# or `IndexError`. Do not run the snippets — reason from the lecture's table,
# then write your three answers as strings in the work cell.
#
# ```python
# # snippet 1
# total_shares + 10          # total_shares was never assigned
#
# # snippet 2
# "AAPL" - 5
#
# # snippet 3
# prices = [10, 20]
# prices[5]
# ```

# %%
answer_1 = ...  # "NameError", "TypeError", or "IndexError"
answer_2 = ...
answer_3 = ...
print(answer_1, answer_2, answer_3)

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Ask, for each: is a name missing (NameError)? Does an operation meet the wrong type (TypeError)? Does a position not exist (IndexError)?
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# answer_1 = "NameError"
# answer_2 = "TypeError"
# answer_3 = "IndexError"
# print(answer_1, answer_2, answer_3)
# ```
#
# **NameError, TypeError, IndexError.** (1) `total_shares` is undefined. (2) subtraction is not defined between text and a number. (3) a list of 2 items has no position 5.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise E2 — Diagnose a SyntaxError
#
# This snippet fails before it even runs:
#
# ```python
# print("Total:", total
# ```
#
# Name the error type, and say exactly what is missing.

# %%
error_type = ...
missing_character = ...
print(error_type, missing_character)

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Count the opening and closing parentheses in the snippet.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# error_type = "SyntaxError"
# missing_character = ")"
# print(error_type, missing_character)
# ```
#
# **SyntaxError, a closing `)`.** Python cannot even start running the line — this is the one error type that is about *shape*, not meaning.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## F · Putting it together

# %% [markdown]
# ### Exercise F1 — Predict a combined expression
#
# Predict the exact text this prints, combining a method call, indexing, the
# return formula, and a format recipe. Then run it to check.

# %%
ticker = "nvda"
closes = [118.4, 121.0, 119.7, 123.5]
change = (closes[-1] - closes[0]) / closes[0]
print(f"{ticker.upper()}: {change:.2%} over the window")

# %% [markdown]
# <details>
# <summary>Hint</summary>
#
# Work it piece by piece: `ticker.upper()` first, then the return using the first and last list items, then the `:.2%` format.
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# ticker = "nvda"
# closes = [118.4, 121.0, 119.7, 123.5]
# change = (closes[-1] - closes[0]) / closes[0]
# print(f"{ticker.upper()}: {change:.2%} over the window")
# ```
#
# **"NVDA: 4.31% over the window".** Four small pieces from four different sections, working together in one line.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise F2 — Average a list of returns
#
# Five daily returns for one week are given below, already computed as
# decimals. Compute their average and print it as a percentage.

# %%
daily_returns = [0.012, -0.004, 0.008, -0.011, 0.006]

average_return = ...
message = ...
message

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The average of a list is `sum(...) / len(...)` — both are functions you already know.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# message = f"Average daily return: {average_return:.2%}"
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# daily_returns = [0.012, -0.004, 0.008, -0.011, 0.006]
#
# average_return = sum(daily_returns) / len(daily_returns)
# message = f"Average daily return: {average_return:.2%}"
# message
# ```
#
# **"Average daily return: 0.22%".** `sum`/`len` generalise instantly to any list, of any length.
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ### Exercise F3 — Compare two stocks over a week
#
# Two stocks' one-week closes are given below. Using only what you learned
# today — no loops, no `if` — compute each stock's return over the week and
# print both, clearly formatted as percentages, in one message. Then, in a
# comment, write which stock had the larger percentage gain.

# %%
stock_x = [54.0, 54.8, 53.9, 55.2, 56.0]
stock_y = [201.0, 203.5, 202.0, 205.0, 208.4]

return_x = ...
return_y = ...
message = ...
message

# which stock had the larger percentage gain?

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Same simple-return formula, applied once to each list's first and last price.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# message = f"stock_x: {return_x:.2%}   stock_y: {return_y:.2%}"
#
# </details>

# %% [markdown]
# <details>
# <summary>Solution</summary>
#
# ```python
# stock_x = [54.0, 54.8, 53.9, 55.2, 56.0]
# stock_y = [201.0, 203.5, 202.0, 205.0, 208.4]
#
# return_x = (stock_x[-1] - stock_x[0]) / stock_x[0]
# return_y = (stock_y[-1] - stock_y[0]) / stock_y[0]
# message = f"stock_x: {return_x:.2%}   stock_y: {return_y:.2%}"
# message
#
# # stock_x had the larger percentage gain
# ```
#
# **"stock_x: 3.70%   stock_y: 3.68%".** Close, but `stock_x` wins — the kind of case where you must read the actual numbers rather than guess from the raw prices (stock_y moved far more in dollar terms, but less in percentage terms).
#
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## Done
#
# That covers every idea from today: runtime state, variables and types,
# functions and methods, lists, and reading errors — plus the simple return
# formula you will use for the rest of the course.
#
# Next: `session_01_case.ipynb`, where the same tools go to work on a full
# year of real Apple and Coca-Cola prices.
