# %% [markdown]
# # Which formula layout survives Colab?
#
# Every block below is the **same five formulas**. Scroll through and note which ones look like a proper two-column table with real mathematics.
#
# Blocks are labelled **A** to **F**. Tell me the letters that render correctly.
#
# Block A is the known-broken one, so it is the control: if A looks fine here, then something else is going on and the rest of this notebook is moot.

# %% [markdown]
# ---
#
# ## A. Markdown table, `$...$`  (the broken control)

# %% [markdown]
# | what | formula |
# |:--|:--|
# | Mean absolute error | $\text{MAE}=\dfrac{1}{n}\sum_i \lvert y_i-\hat{y}_i \rvert$ |
# | Mean squared error | $\text{MSE}=\dfrac{1}{n}\sum_i (y_i-\hat{y}_i)^2$ |
# | Root mean squared error | $\text{RMSE}=\sqrt{\text{MSE}}$ |
# | R squared | $R^2=1-\dfrac{\sum_i (y_i-\hat{y}_i)^2}{\sum_i (y_i-\bar{y})^2}$ |
# | Standardised value | $z_i=\dfrac{x_i-\bar{x}}{s}$ |

# %% [markdown]
# ---
#
# ## B. Markdown table, `\(...\)` delimiters
#
# Same table, but the maths is delimited with `\(` and `\)` instead of `$`. If Colab's breakage comes from pairing `$` signs across rows, this fixes it while keeping the table.

# %% [markdown]
# | what | formula |
# |:--|:--|
# | Mean absolute error | \(\text{MAE}=\dfrac{1}{n}\sum_i \lvert y_i-\hat{y}_i \rvert\) |
# | Mean squared error | \(\text{MSE}=\dfrac{1}{n}\sum_i (y_i-\hat{y}_i)^2\) |
# | Root mean squared error | \(\text{RMSE}=\sqrt{\text{MSE}}\) |
# | R squared | \(R^2=1-\dfrac{\sum_i (y_i-\hat{y}_i)^2}{\sum_i (y_i-\bar{y})^2}\) |
# | Standardised value | \(z_i=\dfrac{x_i-\bar{x}}{s}\) |

# %% [markdown]
# ---
#
# ## C. HTML table, `$...$`
#
# A real `<table>`, so the markdown table parser is never involved. The maths is still LaTeX, typeset in the page after the HTML is laid out.

# %% [markdown]
# <table>
# <tr><th align="left">what</th><th align="left">formula</th></tr>
# <tr><td>Mean absolute error</td><td>$\text{MAE}=\dfrac{1}{n}\sum_i \lvert y_i-\hat{y}_i \rvert$</td></tr>
# <tr><td>Mean squared error</td><td>$\text{MSE}=\dfrac{1}{n}\sum_i (y_i-\hat{y}_i)^2$</td></tr>
# <tr><td>Root mean squared error</td><td>$\text{RMSE}=\sqrt{\text{MSE}}$</td></tr>
# <tr><td>R squared</td><td>$R^2=1-\dfrac{\sum_i (y_i-\hat{y}_i)^2}{\sum_i (y_i-\bar{y})^2}$</td></tr>
# <tr><td>Standardised value</td><td>$z_i=\dfrac{x_i-\bar{x}}{s}$</td></tr>
# </table>

# %% [markdown]
# ---
#
# ## D. HTML table, `\(...\)` delimiters

# %% [markdown]
# <table>
# <tr><th align="left">what</th><th align="left">formula</th></tr>
# <tr><td>Mean absolute error</td><td>\(\text{MAE}=\dfrac{1}{n}\sum_i \lvert y_i-\hat{y}_i \rvert\)</td></tr>
# <tr><td>Mean squared error</td><td>\(\text{MSE}=\dfrac{1}{n}\sum_i (y_i-\hat{y}_i)^2\)</td></tr>
# <tr><td>Root mean squared error</td><td>\(\text{RMSE}=\sqrt{\text{MSE}}\)</td></tr>
# <tr><td>R squared</td><td>\(R^2=1-\dfrac{\sum_i (y_i-\hat{y}_i)^2}{\sum_i (y_i-\bar{y})^2}\)</td></tr>
# <tr><td>Standardised value</td><td>\(z_i=\dfrac{x_i-\bar{x}}{s}\)</td></tr>
# </table>

# %% [markdown]
# ---
#
# ## E. HTML table, plain Unicode, no LaTeX at all
#
# Cannot fail, because nothing has to typeset it. The question is only whether you find it good enough to read.

# %% [markdown]
# <table>
# <tr><th align="left">what</th><th align="left">formula</th></tr>
# <tr><td>Mean absolute error</td><td><code>MAE = (1/n) Σᵢ |yᵢ − ŷᵢ|</code></td></tr>
# <tr><td>Mean squared error</td><td><code>MSE = (1/n) Σᵢ (yᵢ − ŷᵢ)²</code></td></tr>
# <tr><td>Root mean squared error</td><td><code>RMSE = √MSE</code></td></tr>
# <tr><td>R squared</td><td><code>R² = 1 − Σᵢ(yᵢ − ŷᵢ)² / Σᵢ(yᵢ − ȳ)²</code></td></tr>
# <tr><td>Standardised value</td><td><code>zᵢ = (xᵢ − x̄) / s</code></td></tr>
# </table>

# %% [markdown]
# ---
#
# ## F. Bullet list  (what is published right now)

# %% [markdown]
# - **Mean absolute error**: $\text{MAE}=\dfrac{1}{n}\sum_i \lvert y_i-\hat{y}_i \rvert$
# - **Mean squared error**: $\text{MSE}=\dfrac{1}{n}\sum_i (y_i-\hat{y}_i)^2$
# - **Root mean squared error**: $\text{RMSE}=\sqrt{\text{MSE}}$
# - **R squared**: $R^2=1-\dfrac{\sum_i (y_i-\hat{y}_i)^2}{\sum_i (y_i-\bar{y})^2}$
# - **Standardised value**: $z_i=\dfrac{x_i-\bar{x}}{s}$

# %% [markdown]
# ---
#
# Which letters rendered as a proper table with proper mathematics?
